# %%
import warnings
import numpy as np
import pandas as pd
import copy
from pathlib import Path
import torch
import torch.nn as nn

import pytorch_lightning as pl
from pytorch_lightning.callbacks import EarlyStopping, LearningRateMonitor
from pytorch_lightning.loggers import TensorBoardLogger

import pytorch_forecasting
from pytorch_forecasting import Baseline, TemporalFusionTransformer, TimeSeriesDataSet
from pytorch_forecasting.data import GroupNormalizer
from pytorch_forecasting.metrics import SMAPE, PoissonLoss, QuantileLoss

import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

import tensorflow as tf
import tensorboard as tb
tf.io.gfile = tb.compat.tensorflow_stub.io.gfile


device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')  

train_data = pd.read_csv('rosneft/train_data.csv')
gtm = pd.read_csv('rosneft/gtm.csv')
coords = pd.read_csv('rosneft/coords.csv')
sampl_sab = pd.read_csv('rosneft/sample_submission.csv')
train_data["MEASURED_IN_DATE"] = pd.to_datetime(train_data["MEASURED_IN_DATE"])

all_data = pd.read_csv('rosneft/gotov_ebat.csv', index_col='Unnamed: 0')
all_data["MEASURED_IN_DATE"] = pd.to_datetime(all_data["MEASURED_IN_DATE"])
all_data_w_d = all_data.drop(columns=['MEASURED_IN_DATE'])
# Out:
# C:\Users\sahab\anaconda3\lib\site-packages\torchmetrics\utilities\prints.py:36: UserWarning: Torchmetrics v0.9 introduced a new argument class property called `full_state_update` that has
#                 not been set for this class (SMAPE). The property determines if `update` by
#                 default needs access to the full metric state. If this is not the case, significant speedups can be
#                 achieved and we recommend setting this to `False`.
#                 We provide an checking function
#                 `from torchmetrics.utilities import check_forward_full_state_property`
#                 that can be used to check if the `full_state_update=True` (old and potential slower behaviour,
#                 default for now) or if `full_state_update=False` can be used safely.
#
#   warnings.warn(*args, **kwargs)

# %%
transformer_to_do = dict()

for i in all_data['WELL_NAME'].unique():
    df = all_data[all_data['WELL_NAME'] == i]
    need_range = pd.date_range(start=df.MEASURED_IN_DATE.max() + np.timedelta64(1, 'D')
                               , end='2022-09-29')
    transformer_to_do[i] = len(need_range)

transformer_to_do_list = [
    i for i in all_data['WELL_NAME'].unique() if transformer_to_do[i] <= 122
]
rf_to_do_dict = {
    i: transformer_to_do[i] for i in all_data['WELL_NAME'].unique() if transformer_to_do[i] > 122
}

# %%
def zdorovaya_dura_LR(all_data_w_d, batch_size, max_prediction_length=122):
    #L_R
    training = TimeSeriesDataSet(
        data=all_data_w_d, 
        time_idx='time_id',
        target='LIQ_RATE',
        group_ids=['WELL_NAME'],
        allow_missing_timesteps=True,
        add_relative_time_idx=True,
        add_target_scales=True,
        static_categoricals = ['WELL_NAME'],
        time_varying_known_reals=["time_id"],
        time_varying_unknown_reals=[
        "LIQ_RATE",
        "WATER_CUT",
        "CHARWORK",
        "INTAKE",
        ],
        max_prediction_length=max_prediction_length,
        min_encoder_length=1,
        max_encoder_length=2128,
        target_normalizer=GroupNormalizer(
            groups=['WELL_NAME'], transformation="softplus"
        ),
#         lags={'LIQ_RATE': [7, 30, 180]},
    )
    
    validation = TimeSeriesDataSet.from_dataset(training, all_data_w_d
                                                , predict=True, stop_randomization=True)
    train_dataloader = training.to_dataloader(train=True, batch_size=batch_size, num_workers=0)
    val_dataloader = validation.to_dataloader(train=False, batch_size=batch_size * 10
                                              , num_workers=0)
    
    lr_logger = LearningRateMonitor()
    early_stop_callback = EarlyStopping(monitor="val_loss", min_delta=1e-4
                                        , patience=10, verbose=False, mode="min")
    logger = TensorBoardLogger("lightning_logs")

    trainer = pl.Trainer(
        max_epochs=300,
        gpus=1,
        enable_model_summary=True,
        gradient_clip_val=0.1,
        limit_train_batches=30,
        callbacks=[lr_logger, early_stop_callback],
        logger=logger,
#         default_root_dir = "rosneft/TFT/LR/"
    )

    tft = TemporalFusionTransformer.from_dataset(
        training,
        learning_rate=0.01,
        hidden_size=16,
        attention_head_size=1,
        dropout=0.1,
        hidden_continuous_size=8,
        loss=QuantileLoss(),
        log_interval=10,
        output_size=7,
        reduce_on_plateau_patience=4,
    )
    
#     tft = TemporalFusionTransformer \
#             .load_from_checkpoint('lightning_logs/lightning_logs/version_46/checkpoints/epoch=99-step=3000.ckpt')
    
    trainer.fit(
    tft,
    train_dataloaders=train_dataloader,
    val_dataloaders=val_dataloader,
    )
    
    return tft, tft.predict(all_data_w_d)

tft_LR, pred_LR = zdorovaya_dura_LR(all_data_w_d, 128)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#    | Name                               | Type                            | Params
# ----------------------------------------------------------------------------------------
# 0  | loss                               | QuantileLoss                    | 0
# 1  | logging_metrics                    | ModuleList                      | 0
# 2  | input_embeddings                   | MultiEmbedding                  | 2.9 K
# 3  | prescalers                         | ModuleDict                      | 144
# 4  | static_variable_selection          | VariableSelectionNetwork        | 1.9 K
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 3.7 K
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 1.2 K
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 1.1 K
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 1.1 K
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 1.1 K
# 10 | static_context_enrichment          | GatedResidualNetwork            | 1.1 K
# 11 | lstm_encoder                       | LSTM                            | 2.2 K
# 12 | lstm_decoder                       | LSTM                            | 2.2 K
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 544
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 32
# 15 | static_enrichment                  | GatedResidualNetwork            | 1.4 K
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 1.1 K
# 17 | post_attn_gate_norm                | GateAddNorm                     | 576
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 1.1 K
# 19 | pre_output_gate_norm               | GateAddNorm                     | 576
# 20 | output_layer                       | Linear                          | 119
# ----------------------------------------------------------------------------------------
# 23.8 K    Trainable params
# 0         Non-trainable params
# 23.8 K    Total params
# 0.095     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]

# %%
def zdorovaya_dura_WC(all_data_w_d, batch_size, max_prediction_length=122):
    #W_C
    training = TimeSeriesDataSet(
        data=all_data_w_d, 
        time_idx='time_id',
        target='WATER_CUT',
        group_ids=['WELL_NAME'],
        allow_missing_timesteps=True,
        add_relative_time_idx=True,
        add_target_scales=True,
        static_categoricals = ['WELL_NAME'],
        time_varying_known_reals=["time_id"],
        time_varying_unknown_reals=[
        "LIQ_RATE",
        "WATER_CUT",
        "CHARWORK",
        "INTAKE",
        ],
        max_prediction_length=max_prediction_length,
        min_encoder_length=1,
        target_normalizer=GroupNormalizer(
            groups=['WELL_NAME'], transformation="softplus"
        ),
        
    )
    
    validation = TimeSeriesDataSet.from_dataset(training, all_data_w_d
                                                , predict=True, stop_randomization=True)
    train_dataloader = training.to_dataloader(train=True, batch_size=batch_size, num_workers=0)
    val_dataloader = validation.to_dataloader(train=False
                                              , batch_size=batch_size * 10, num_workers=0)
    
    lr_logger = LearningRateMonitor()
    early_stop_callback = EarlyStopping(monitor="val_loss", min_delta=1e-4
                                        , patience=10, verbose=False, mode="min")
    logger = TensorBoardLogger("lightning_logs")

    trainer = pl.Trainer(
        max_epochs=300,
        gpus=1,
        enable_model_summary=True,
        gradient_clip_val=0.1,
        limit_train_batches=30,
        callbacks=[lr_logger, early_stop_callback],
        logger=logger,
        default_root_dir = "rosneft/TFT/WC/"
    )

    tft = TemporalFusionTransformer.from_dataset(
        training,
        learning_rate=0.01,
        hidden_size=16,
        attention_head_size=1,
        dropout=0.1,
        hidden_continuous_size=8,
        loss=QuantileLoss(),
        log_interval=10,
        output_size=7,
        reduce_on_plateau_patience=4,
    )
    
    trainer.fit(
    tft,
    train_dataloaders=train_dataloader,
    val_dataloaders=val_dataloader,
    )
#     tft = TemporalFusionTransformer \
#             .load_from_checkpoint('lightning_logs/lightning_logs/version_47/checkpoints/epoch=99-step=3000.ckpt')
    return tft, tft.predict(all_data_w_d)

tft_WC, pred_WC = zdorovaya_dura_WC(all_data_w_d, 128)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#    | Name                               | Type                            | Params
# ----------------------------------------------------------------------------------------
# 0  | loss                               | QuantileLoss                    | 0
# 1  | logging_metrics                    | ModuleList                      | 0
# 2  | input_embeddings                   | MultiEmbedding                  | 2.9 K
# 3  | prescalers                         | ModuleDict                      | 144
# 4  | static_variable_selection          | VariableSelectionNetwork        | 1.9 K
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 3.7 K
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 1.2 K
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 1.1 K
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 1.1 K
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 1.1 K
# 10 | static_context_enrichment          | GatedResidualNetwork            | 1.1 K
# 11 | lstm_encoder                       | LSTM                            | 2.2 K
# 12 | lstm_decoder                       | LSTM                            | 2.2 K
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 544
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 32
# 15 | static_enrichment                  | GatedResidualNetwork            | 1.4 K
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 1.1 K
# 17 | post_attn_gate_norm                | GateAddNorm                     | 576
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 1.1 K
# 19 | pre_output_gate_norm               | GateAddNorm                     | 576
# 20 | output_layer                       | Linear                          | 119
# ----------------------------------------------------------------------------------------
# 23.8 K    Trainable params
# 0         Non-trainable params
# 23.8 K    Total params
# 0.095     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]

# %%
# pd.DataFrame(pred_WC.detach().numpy()).transpose()
# pd.DataFrame(pred_LR.detach().numpy()).transpose()

# %%
answer = pd.DataFrame()
for i in transformer_to_do_list:
    df = all_data.copy()
    df = df[df['WELL_NAME'] == i]
    df.index = range(len(df))
    date_range = pd.date_range(start=df["MEASURED_IN_DATE"][len(df)-1] 
                               + np.timedelta64(1, 'D')
                               , end=df["MEASURED_IN_DATE"][len(df)-1] 
                               + np.timedelta64(122, 'D'))
    df = df.drop(columns=['MEASURED_IN_DATE'])
    pred_LR = tft_LR.predict(df)
    pred_WC = tft_WC.predict(df)
    pred_df = pd.DataFrame()
    pred_df['MEASURED_IN_DATE'] = date_range
    pred_df['WELL_NAME'] = i
    pred_df['LIQ_RATE'] = pred_LR.detach().numpy()[0]
    pred_df['WATER_CUT'] = pred_WC.detach().numpy()[0]
    answer = pd.concat([answer, pred_df])
# answer

# %% [markdown]
# Random forest

# %%
all_data
# Out:
#        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT   P_ZAB  INTAKE  \
# 17437        2016-08-02       0.0     690.0        0.5  159.19     0.0
# 17438        2016-08-03       0.0     690.0        0.5  159.19     0.0
# 17439        2016-08-04       0.0     690.0        0.5  153.19     0.0
# 17440        2016-08-05       0.0     780.0        0.5  151.21     0.0
# 17441        2016-08-06       0.0     780.0        0.5  151.21     0.0
# ...                 ...       ...       ...        ...     ...     ...
# 104377       2022-05-31       0.0     339.0       70.0   55.69     0.0
# 53662        2022-05-31       0.0     225.0       58.0   75.48     0.0
# 54379        2022-05-31       0.0     170.0       91.0  178.15     0.0
# 104892       2022-05-31       0.0     208.0       88.0  113.02     0.0
# 122411       2022-05-31       0.0     328.0       70.0   60.73     0.0
#
#                                                 WELL_NAME  time_id
# 17437   aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...        0
# 17438   aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...        1
# 17439   aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...        2
# 17440   aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...        3
# 17441   aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...        4
# ...                                                   ...      ...
# 104377  18ea8ca26bcabaac4fd073a00ba741a627f3649a6983a7...     2128
# 53662   b04d54ff8a670262e81f0e0b514a32e03baa85200cd9f2...     2128
# 54379   b694e479af091b82198c24a43195efbb9578a4f0e2e163...     2128
# 104892  139e20fe864acf1a4b831ac25d417fe70725cbee85197c...     2128
# 122411  1de41569155b66df7355c8fc7a53e80333aea79dc9bb37...     2128
#
# [122412 rows x 8 columns]

# %%
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit, RandomizedSearchCV

# %%
def plot_train_valid(model, X_train, y_train, X_test, y_test):
    train_indice = range(X_train.shape[0])
    test_indice = range(X_tran.shape[0], X_train.shape[0] + X_test.shape[0])
    
    plt.figure(figsize=(12, 6))
    sns.lineplot(x=train_indice, y=y_train)
    sns.lineplot(x=test_indice, y=model.predict(X_test))
    sns.lineplot(x=test_indice, y=y_test)
    
    plt.axvline(X.shape[0], linestyle='--', c='red')

    plt.legend(['Train', 'Valid', 'Prediction', 'Train/valid sep'])
    plt.show()

def predict_step_by_step(model, row, days):
    forecasting_for_days = []
    new_arr_to_predict = row.to_numpy().tolist()
    for i in range(days):
        tensor_to_predict = np.array(new_arr_to_predict)

        predict = model.predict(tensor_to_predict)[0]
        forecasting_for_days.append(predict)
        new_arr_to_predict = [new_arr_to_predict[0][:-1]]
        new_arr_to_predict[0].insert(0, forecasting_for_days[-1])
    
    return forecasting_for_days

def lag_features_liquid_rate(df, lags):
    for lag in lags:
        df[f"lag_t-{lag}"] = df.groupby(["CHARWORK"])["LIQ_RATE"].transform(
            lambda x: x.shift(lag))
    return df

def lag_features_water_cut(df, lags):
    for lag in lags:
        df[f"lag_t-{lag}"] = df.groupby(["CHARWORK"])["WATER_CUT"].transform(
            lambda x: x.shift(lag))
    return df

# %%
from sklearn.neighbors import KNeighborsRegressor

LAG_WINDOW_SIZE = 30

# Рустам - для вас 

# train_data = pd.read_csv('rosneft/train_data.csv')
# sampl_sab = pd.read_csv('rosneft/sample_submission.csv')


train_data = pd.read_csv('rosneft/train_data.csv')
sampl_sab = pd.read_csv('rosneft/sample_submission.csv')
train_data["MEASURED_IN_DATE"] = pd.to_datetime(train_data["MEASURED_IN_DATE"])

cols_to_select = ['MEASURED_IN_DATE', 'WELL_NAME', 'CHARWORK', 'LIQ_RATE', 'WATER_CUT',
       'P_ZAB', 'INTAKE']
train_data = train_data[cols_to_select]


# Filling date gaps with KNN
knn_train = train_data.dropna().drop(columns=['WELL_NAME', 'MEASURED_IN_DATE'
                                     , 'P_ZAB', 'LIQ_RATE', 'WATER_CUT'])
knn_train.CHARWORK = knn_train.CHARWORK.apply(lambda x: int(x == 'НАГ'))
X, y = knn_train, train_data.dropna().P_ZAB
knn = KNeighborsRegressor(n_neighbors=7)
knn.fit(X, y)


knn_na = train_data[~(train_data.index.isin(knn_train.index))] \
            .drop(columns=['WELL_NAME', 'MEASURED_IN_DATE'
                            , 'P_ZAB', 'LIQ_RATE', 'WATER_CUT'])
knn_na.CHARWORK = knn_na.CHARWORK.apply(lambda x: int(x == 'НАГ'))
preds = knn.predict(knn_na)


k = 0
for i, row in train_data.iterrows():
    if i in knn_na.index:
        train_data.at[i, 'P_ZAB'] = preds[k]
        k += 1
train_data.CHARWORK = train_data.CHARWORK.apply(lambda x: int(x == 'НАГ'))
well_names = train_data['WELL_NAME'].unique()


# Get missing days for each well
date_miss_dict = dict()
for i in well_names:
    df = train_data[train_data.WELL_NAME == i]
    df.index = range(len(df))
    date_range = pd.date_range(start=df.MEASURED_IN_DATE[0]
                               , end=df["MEASURED_IN_DATE"][len(df)-1])
    date_train_i, date_i, date_miss = 0, 0, []
    while date_train_i < len(df["MEASURED_IN_DATE"]) and date_i < len(date_range):
        if df.MEASURED_IN_DATE[date_train_i] == date_range[date_i]:
            date_i += 1
            date_train_i += 1
        else:
            date_i += 1
            date_miss.append(date_range[date_i])
    date_miss_ser = pd.Series(date_miss)
    ans_df = df.merge(pd.DataFrame(date_miss_ser), how="outer"
                      , left_on="MEASURED_IN_DATE", right_on=0)
    ans_df = ans_df.drop(columns=[0, 'WELL_NAME'])
    date_miss_dict[i] = ans_df

# Fill missing days with rolling mean values    
for key in date_miss_dict.keys():
    date_miss_dict[key] = date_miss_dict[key].sort_values(by='MEASURED_IN_DATE')
    
    curr_length = 0
    max_missing_seq = -1

    for i in date_miss_dict[key].index:    
        if date_miss_dict[key].loc[[i]].isna().any().any():
            curr_length += 1
        else:
            max_missing_seq = max(curr_length, max_missing_seq)
            curr_length = 0
        i += 1  
        
    date_miss_dict[key] = date_miss_dict[key].fillna(
        date_miss_dict[key].rolling(max_missing_seq + 1, min_periods=1).mean()
    )

# %%
rf_date_miss_dict = {
    key: value for key, value in date_miss_dict.items() 
    if key in rf_to_do_dict.keys()
}

# %%
rf_to_do_dict
# Out:
# {'debcf7a160692239563af8a9c8ba32c4ba067e747f19c8073055e2be5aeb4022': 253,
#  '114183900f2d540609911971f3ae3f3d42ab8b4fa9252d0c4076b00d482c1594': 216,
#  '8d4b4b4f0140179b1c94722f3d39100bcde8f3c39415983813c74bd52cf1ab3c': 336,
#  '2ceb0e2b3c28cc1b3c3f8dec7ad56148dbf6ea77f9ffc832f4c4b9ce845d9bb7': 133}

# %%
import sklearn
sklearn.metrics.SCORERS.keys()
# Out:
# dict_keys(['explained_variance', 'r2', 'max_error', 'matthews_corrcoef', 'neg_median_absolute_error', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_root_mean_squared_error', 'neg_mean_poisson_deviance', 'neg_mean_gamma_deviance', 'accuracy', 'top_k_accuracy', 'roc_auc', 'roc_auc_ovr', 'roc_auc_ovo', 'roc_auc_ovr_weighted', 'roc_auc_ovo_weighted', 'balanced_accuracy', 'average_precision', 'neg_log_loss', 'neg_brier_score', 'adjusted_rand_score', 'rand_score', 'homogeneity_score', 'completeness_score', 'v_measure_score', 'mutual_info_score', 'adjusted_mutual_info_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard_samples', 'jaccard_weighted'])

# %%
# Forecast for most wells

rf_forecasts_dict_WC = dict()
best_wc_models = []

for c, i in enumerate(rf_date_miss_dict):
    train_data = rf_date_miss_dict[i].drop(columns=['P_ZAB', 'INTAKE', 'LIQ_RATE'])
    train_with_lags = lag_features_water_cut(train_data, lags=[*range(1, LAG_WINDOW_SIZE + 1)])
    train_with_lags = train_with_lags.dropna()
    y = train_with_lags['WATER_CUT']
    if len(train_with_lags['MEASURED_IN_DATE']) == 0:
        continue
    else:
        last_date = np.array(train_with_lags['MEASURED_IN_DATE'])[-1]
        train_with_lags = train_with_lags.drop(columns=['WATER_CUT'
                                                        , 'MEASURED_IN_DATE', 'CHARWORK'])
        index_to_predict = pd.date_range(start=last_date + np.timedelta64(1, 'D')
                                         , end=last_date + np.timedelta64(rf_to_do_dict[i], 'D'))
        
            
        model = RandomForestRegressor(random_state=1984)
        params = {
            'n_estimators': [30, 60, 100],
            'max_depth': [10, 12, 15, None],
            'min_samples_split': [3, 5, 7, 10],
            'min_samples_leaf': [1, 3, 5],
            'random_state': [2077]
        }
        
        search = RandomizedSearchCV(model, params, scoring='neg_mean_squared_error'
                              , cv=TimeSeriesSplit(n_splits=5), n_jobs=-1, random_state=1488)
        
        search.fit(train_with_lags, y)
        
        forecast = pd.Series(predict_step_by_step(search, train_with_lags.tail(1)
                                                  , rf_to_do_dict[i])
                             , index=index_to_predict)
        rf_forecasts_dict_WC[i] = forecast
        
        
        print('Score:\t', -search.score(train_with_lags, y))
        best_wc_models.append(search.best_estimator_)
# Out:
# Score:	 0.5246519726694854
# Score:	 6.7452785965768305
# Score:	 19.659933076186658
# Score:	 0.0499584358729787

# %%
rf_forecasts_dict_LR = dict()
best_lr_models = []

for c, i in enumerate(rf_date_miss_dict):
    train_data = rf_date_miss_dict[i].drop(columns=['P_ZAB', 'INTAKE', 'WATER_CUT'])
    train_with_lags = lag_features_liquid_rate(train_data
                                               , lags=[*range(1, LAG_WINDOW_SIZE + 1)])
    train_with_lags = train_with_lags.dropna()
    y = train_with_lags['LIQ_RATE']
    if len(train_with_lags['MEASURED_IN_DATE']) == 0:
        continue
    else:
        last_date = np.array(train_with_lags['MEASURED_IN_DATE'])[-1]
        train_with_lags = train_with_lags.drop(columns=['LIQ_RATE'
                                                        , 'MEASURED_IN_DATE', 'CHARWORK'])
        index_to_predict = pd.date_range(start=last_date + np.timedelta64(1, 'D')
                                         , end=last_date \
                                         + np.timedelta64(rf_to_do_dict[i], 'D'))
        
        model = RandomForestRegressor()
        params = {
            'n_estimators': [30, 60, 100],
            'max_depth': [10, 12, 15, None],
            'min_samples_split': [3, 5, 7, 10],
            'min_samples_leaf': [1, 3, 5],
            'random_state': [2077]
        }
        
        search = RandomizedSearchCV(model, params, scoring='neg_mean_absolute_error'
                              , cv=TimeSeriesSplit(n_splits=5), n_jobs=-1, random_state=66)
        
        search.fit(train_with_lags, y)
        
        forecast = pd.Series(predict_step_by_step(search, train_with_lags.tail(1)
                                                  , rf_to_do_dict[i])
                             , index=index_to_predict)
        rf_forecasts_dict_LR[i] = forecast
        
        
        print('Score:\t', -search.score(train_with_lags, y))
        best_lr_models.append(search.best_estimator_)
# Out:
# Score:	 2.1916459819760794
# Score:	 1.8189068398639154
# Score:	 0.621109189585627
# Score:	 2.01984875541126

# %% [markdown]
# Скор на WATER_CUT пиздец
#
# - Score:	 0.5341674113649033
# - Score:	 6.745349770013871
# - Score:	 19.606119368192207
# - Score:	 0.09145253840877589

# %%
from sklearn.linear_model import Lasso
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error



def drop_constant_columns(df):
    return df.loc[:, (df != df.iloc[0]).any()]
    

cb_forecasts_dict_WC = dict()
best_wc_cbrs = []
scores = []

for c, i in enumerate(rf_date_miss_dict):
    train_data = rf_date_miss_dict[i].drop(columns=['P_ZAB', 'INTAKE', 'LIQ_RATE'])
    train_with_lags = lag_features_water_cut(train_data, lags=[*range(1, LAG_WINDOW_SIZE + 1)])
    train_with_lags = train_with_lags.dropna()
    y = train_with_lags['WATER_CUT']
    


    if len(train_with_lags['MEASURED_IN_DATE']) == 0:
        continue
    else:
        last_date = np.array(train_with_lags['MEASURED_IN_DATE'])[-1]
        train_with_lags = train_with_lags.drop(columns=['WATER_CUT'
                                                        , 'MEASURED_IN_DATE', 'CHARWORK'])
        train_with_lags = drop_constant_columns(train_with_lags)


        index_to_predict = pd.date_range(start=last_date + np.timedelta64(1, 'D')
                                         , end=last_date + np.timedelta64(rf_to_do_dict[i], 'D'))
        
        
        model = CatBoostRegressor(iterations=4000, task_type="GPU" ,
                           devices='0:1')

        params = {
            'random_seed': [2077],
#             'n_estimators': [115, 228, 300],
#             'max_depth': [5, 7, 9],
#             'learning_rate': [9e-3, 9e-2]
        }
        
#         search = GridSearchCV(model, params, scoring='neg_mean_absolute_error'
#                               , cv=TimeSeriesSplit(n_splits=5), n_jobs=-1)
#         search.fit(train_with_lags, y)
        model.fit(train_with_lags, y, plot=True)
        
        forecast = pd.Series(predict_step_by_step(model, train_with_lags.tail(1)
                                                  , rf_to_do_dict[i])
                             , index=index_to_predict)
        cb_forecasts_dict_WC[i] = forecast
    
        scores.append(-search.score(train_with_lags, y))
        best_wc_cbrs.append(search.best_estimator_)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Warning: less than 75% gpu memory available for training. Free: 4215 Total: 6143.5
# Learning rate set to 0.018176
# 0:	learn: 22.6898507	total: 16.2ms	remaining: 1m 4s
# 1:	learn: 22.2952579	total: 26.2ms	remaining: 52.4s
# 2:	learn: 21.9073467	total: 36ms	remaining: 48s
# 3:	learn: 21.5255408	total: 46.2ms	remaining: 46.2s
# 4:	learn: 21.1522983	total: 56.3ms	remaining: 45s
# 5:	learn: 20.7848121	total: 66.1ms	remaining: 44s
# 6:	learn: 20.4247276	total: 76ms	remaining: 43.4s
# 7:	learn: 20.0706896	total: 85.9ms	remaining: 42.9s
# 8:	learn: 19.7229471	total: 95.8ms	remaining: 42.5s
# 9:	learn: 19.3825442	total: 105ms	remaining: 42s
# 10:	learn: 19.0473156	total: 115ms	remaining: 41.8s
# 11:	learn: 18.7171173	total: 125ms	remaining: 41.5s
# 12:	learn: 18.3940519	total: 135ms	remaining: 41.4s
# 13:	learn: 18.0769125	total: 145ms	remaining: 41.3s
# 14:	learn: 17.7655293	total: 155ms	remaining: 41.3s
# 15:	learn: 17.4579301	total: 165ms	remaining: 41.1s
# 16:	learn: 17.1574066	total: 175ms	remaining: 41s
# 17:	learn: 16.8638451	total: 185ms	remaining: 40.9s
# 18:	learn: 16.5726006	total: 195ms	remaining: 40.8s
# 19:	learn: 16.2851606	total: 204ms	remaining: 40.7s
# 20:	learn: 16.0054555	total: 215ms	remaining: 40.7s
# 21:	learn: 15.7311602	total: 224ms	remaining: 40.6s
# 166:	learn: 1.9514221	total: 1.57s	remaining: 36s
# 167:	learn: 1.9360294	total: 1.58s	remaining: 36s
# 168:	learn: 1.9199184	total: 1.59s	remaining: 36s
# 169:	learn: 1.9049229	total: 1.6s	remaining: 36s
# 170:	learn: 1.8914221	total: 1.6s	remaining: 35.9s
# 171:	learn: 1.8783685	total: 1.61s	remaining: 35.9s
# 172:	learn: 1.8650127	total: 1.62s	remaining: 35.9s
# 173:	learn: 1.8523494	total: 1.63s	remaining: 35.9s
# 174:	learn: 1.8397711	total: 1.64s	remaining: 35.9s
# 175:	learn: 1.8273784	total: 1.65s	remaining: 35.9s
# 176:	learn: 1.8145712	total: 1.66s	remaining: 35.9s
# 177:	learn: 1.8010477	total: 1.67s	remaining: 35.8s
# 178:	learn: 1.7895580	total: 1.68s	remaining: 35.8s
# 179:	learn: 1.7782648	total: 1.69s	remaining: 35.8s
# 180:	learn: 1.7653596	total: 1.7s	remaining: 35.8s
# 181:	learn: 1.7547740	total: 1.71s	remaining: 35.8s
# 182:	learn: 1.7414359	total: 1.71s	remaining: 35.8s
# 183:	learn: 1.7310637	total: 1.72s	remaining: 35.8s
# 184:	learn: 1.7211615	total: 1.73s	remaining: 35.7s
# 185:	learn: 1.7105840	total: 1.74s	remaining: 35.7s
# 186:	learn: 1.7015370	total: 1.75s	remaining: 35.7s
# 187:	learn: 1.6922068	total: 1.76s	remaining: 35.7s
# 188:	learn: 1.6830620	total: 1.77s	remaining: 35.7s
# 189:	learn: 1.6749853	total: 1.78s	remaining: 35.7s
# 190:	learn: 1.6679861	total: 1.79s	remaining: 35.7s
# 191:	learn: 1.6580527	total: 1.8s	remaining: 35.6s
# 192:	learn: 1.6500317	total: 1.81s	remaining: 35.6s
# 193:	learn: 1.6426086	total: 1.81s	remaining: 35.6s
# 194:	learn: 1.6344341	total: 1.82s	remaining: 35.6s
# 195:	learn: 1.6265751	total: 1.83s	remaining: 35.6s
# 196:	learn: 1.6185109	total: 1.84s	remaining: 35.6s
# 197:	learn: 1.6100352	total: 1.85s	remaining: 35.6s
# 198:	learn: 1.6025245	total: 1.86s	remaining: 35.5s
# 199:	learn: 1.5964552	total: 1.87s	remaining: 35.5s
# 200:	learn: 1.5896659	total: 1.88s	remaining: 35.5s
# 201:	learn: 1.5820079	total: 1.89s	remaining: 35.5s
# 202:	learn: 1.5741227	total: 1.9s	remaining: 35.5s
# 203:	learn: 1.5683907	total: 1.91s	remaining: 35.5s
# 204:	learn: 1.5616053	total: 1.91s	remaining: 35.4s
# 205:	learn: 1.5548994	total: 1.92s	remaining: 35.4s
# 206:	learn: 1.5488350	total: 1.93s	remaining: 35.4s
# 207:	learn: 1.5424514	total: 1.94s	remaining: 35.4s
# 208:	learn: 1.5364700	total: 1.95s	remaining: 35.4s
# 209:	learn: 1.5301633	total: 1.96s	remaining: 35.4s
# 210:	learn: 1.5246296	total: 1.97s	remaining: 35.3s
# 211:	learn: 1.5185241	total: 1.98s	remaining: 35.3s
# 212:	learn: 1.5136508	total: 1.99s	remaining: 35.3s
# 213:	learn: 1.5079909	total: 2s	remaining: 35.3s
# 592:	learn: 1.0956272	total: 5.41s	remaining: 31.1s
# 593:	learn: 1.0947374	total: 5.42s	remaining: 31.1s
# 594:	learn: 1.0942666	total: 5.43s	remaining: 31.1s
# 595:	learn: 1.0923714	total: 5.44s	remaining: 31.1s
# 596:	learn: 1.0903138	total: 5.45s	remaining: 31.1s
# 597:	learn: 1.0896900	total: 5.46s	remaining: 31.1s
# 598:	learn: 1.0896847	total: 5.47s	remaining: 31.1s
# 599:	learn: 1.0896797	total: 5.48s	remaining: 31s
# 600:	learn: 1.0895888	total: 5.49s	remaining: 31s
# 601:	learn: 1.0895738	total: 5.5s	remaining: 31s
# 602:	learn: 1.0895384	total: 5.5s	remaining: 31s
# 603:	learn: 1.0885670	total: 5.51s	remaining: 31s
# 604:	learn: 1.0885421	total: 5.52s	remaining: 31s
# 605:	learn: 1.0874740	total: 5.53s	remaining: 31s
# 606:	learn: 1.0867814	total: 5.54s	remaining: 31s
# 607:	learn: 1.0859421	total: 5.55s	remaining: 31s
# 608:	learn: 1.0858785	total: 5.56s	remaining: 31s
# 609:	learn: 1.0858156	total: 5.57s	remaining: 31s
# 610:	learn: 1.0856098	total: 5.58s	remaining: 30.9s
# 611:	learn: 1.0847869	total: 5.59s	remaining: 30.9s
# 612:	learn: 1.0844543	total: 5.6s	remaining: 30.9s
# 613:	learn: 1.0841014	total: 5.61s	remaining: 30.9s
# 614:	learn: 1.0840819	total: 5.62s	remaining: 30.9s
# 615:	learn: 1.0825647	total: 5.63s	remaining: 30.9s
# 616:	learn: 1.0825182	total: 5.63s	remaining: 30.9s
# 617:	learn: 1.0824860	total: 5.64s	remaining: 30.9s
# 618:	learn: 1.0818446	total: 5.65s	remaining: 30.9s
# 619:	learn: 1.0817511	total: 5.66s	remaining: 30.9s
# 620:	learn: 1.0817392	total: 5.67s	remaining: 30.9s
# 621:	learn: 1.0816989	total: 5.68s	remaining: 30.9s
# 622:	learn: 1.0816464	total: 5.69s	remaining: 30.8s
# 623:	learn: 1.0815668	total: 5.7s	remaining: 30.8s
# 624:	learn: 1.0815084	total: 5.71s	remaining: 30.8s
# 625:	learn: 1.0808879	total: 5.72s	remaining: 30.8s
# 626:	learn: 1.0808845	total: 5.73s	remaining: 30.8s
# 627:	learn: 1.0808724	total: 5.74s	remaining: 30.8s
# 628:	learn: 1.0799383	total: 5.74s	remaining: 30.8s
# 629:	learn: 1.0788324	total: 5.75s	remaining: 30.8s
# 630:	learn: 1.0783402	total: 5.76s	remaining: 30.8s
# 631:	learn: 1.0783365	total: 5.77s	remaining: 30.8s
# 632:	learn: 1.0783331	total: 5.78s	remaining: 30.8s
# 633:	learn: 1.0773510	total: 5.79s	remaining: 30.7s
# 634:	learn: 1.0770709	total: 5.8s	remaining: 30.7s
# 635:	learn: 1.0764483	total: 5.81s	remaining: 30.7s
# 636:	learn: 1.0763929	total: 5.82s	remaining: 30.7s
# 637:	learn: 1.0763826	total: 5.83s	remaining: 30.7s
# 638:	learn: 1.0763027	total: 5.84s	remaining: 30.7s
# 639:	learn: 1.0762370	total: 5.84s	remaining: 30.7s
# 640:	learn: 1.0761883	total: 5.86s	remaining: 30.7s
# 641:	learn: 1.0761266	total: 5.86s	remaining: 30.7s
# 642:	learn: 1.0751842	total: 5.87s	remaining: 30.7s
# 643:	learn: 1.0751154	total: 5.88s	remaining: 30.7s
# 644:	learn: 1.0750581	total: 5.89s	remaining: 30.6s
# 645:	learn: 1.0750318	total: 5.9s	remaining: 30.6s
# 646:	learn: 1.0742498	total: 5.91s	remaining: 30.6s
# 647:	learn: 1.0742467	total: 5.92s	remaining: 30.6s
# 648:	learn: 1.0742030	total: 5.93s	remaining: 30.6s
# 649:	learn: 1.0738311	total: 5.94s	remaining: 30.6s
# 650:	learn: 1.0719060	total: 5.95s	remaining: 30.6s
# 651:	learn: 1.0718966	total: 5.96s	remaining: 30.6s
# 652:	learn: 1.0714065	total: 5.96s	remaining: 30.6s
# 653:	learn: 1.0713583	total: 5.97s	remaining: 30.6s
# 654:	learn: 1.0712309	total: 5.98s	remaining: 30.6s
# 655:	learn: 1.0707808	total: 5.99s	remaining: 30.5s
# 656:	learn: 1.0707719	total: 6s	remaining: 30.5s
# 657:	learn: 1.0696612	total: 6.01s	remaining: 30.5s
# 658:	learn: 1.0695883	total: 6.02s	remaining: 30.5s
# 659:	learn: 1.0695744	total: 6.03s	remaining: 30.5s
# 660:	learn: 1.0690021	total: 6.04s	remaining: 30.5s
# 661:	learn: 1.0689758	total: 6.05s	remaining: 30.5s
# 662:	learn: 1.0689135	total: 6.05s	remaining: 30.5s
# 663:	learn: 1.0688662	total: 6.06s	remaining: 30.5s
# 664:	learn: 1.0670225	total: 6.07s	remaining: 30.5s
# 665:	learn: 1.0669827	total: 6.08s	remaining: 30.5s
# 666:	learn: 1.0669260	total: 6.09s	remaining: 30.4s
# 667:	learn: 1.0663154	total: 6.1s	remaining: 30.4s
# 668:	learn: 1.0643134	total: 6.11s	remaining: 30.4s
# 669:	learn: 1.0641006	total: 6.12s	remaining: 30.4s
# 670:	learn: 1.0640643	total: 6.13s	remaining: 30.4s
# 671:	learn: 1.0633502	total: 6.14s	remaining: 30.4s
# 672:	learn: 1.0616564	total: 6.15s	remaining: 30.4s
# 673:	learn: 1.0616082	total: 6.16s	remaining: 30.4s
# 674:	learn: 1.0614523	total: 6.17s	remaining: 30.4s
# 675:	learn: 1.0608309	total: 6.17s	remaining: 30.4s
# 676:	learn: 1.0607904	total: 6.18s	remaining: 30.4s
# 677:	learn: 1.0607491	total: 6.19s	remaining: 30.3s
# 678:	learn: 1.0607148	total: 6.2s	remaining: 30.3s
# 679:	learn: 1.0606509	total: 6.21s	remaining: 30.3s
# 680:	learn: 1.0606050	total: 6.22s	remaining: 30.3s
# 681:	learn: 1.0605881	total: 6.23s	remaining: 30.3s
# 682:	learn: 1.0596521	total: 6.24s	remaining: 30.3s
# 683:	learn: 1.0588828	total: 6.25s	remaining: 30.3s
# 684:	learn: 1.0584084	total: 6.26s	remaining: 30.3s
# 685:	learn: 1.0583679	total: 6.27s	remaining: 30.3s
# 686:	learn: 1.0583294	total: 6.28s	remaining: 30.3s
# 687:	learn: 1.0574410	total: 6.29s	remaining: 30.3s
# 688:	learn: 1.0568743	total: 6.29s	remaining: 30.2s
# 689:	learn: 1.0568660	total: 6.3s	remaining: 30.2s
# 690:	learn: 1.0568145	total: 6.31s	remaining: 30.2s
# 691:	learn: 1.0563583	total: 6.32s	remaining: 30.2s
# 692:	learn: 1.0563074	total: 6.33s	remaining: 30.2s
# 693:	learn: 1.0562612	total: 6.34s	remaining: 30.2s
# 694:	learn: 1.0551959	total: 6.35s	remaining: 30.2s
# 695:	learn: 1.0551663	total: 6.36s	remaining: 30.2s
# 696:	learn: 1.0546708	total: 6.37s	remaining: 30.2s
# 697:	learn: 1.0546351	total: 6.38s	remaining: 30.2s
# 698:	learn: 1.0532017	total: 6.38s	remaining: 30.2s
# 699:	learn: 1.0531732	total: 6.39s	remaining: 30.1s
# 700:	learn: 1.0528863	total: 6.4s	remaining: 30.1s
# 701:	learn: 1.0528526	total: 6.41s	remaining: 30.1s
# 702:	learn: 1.0524622	total: 6.42s	remaining: 30.1s
# 703:	learn: 1.0519378	total: 6.43s	remaining: 30.1s
# 704:	learn: 1.0514650	total: 6.44s	remaining: 30.1s
# 705:	learn: 1.0498756	total: 6.45s	remaining: 30.1s
# 706:	learn: 1.0498509	total: 6.46s	remaining: 30.1s
# 707:	learn: 1.0498489	total: 6.47s	remaining: 30.1s
# 708:	learn: 1.0498217	total: 6.48s	remaining: 30.1s
# 709:	learn: 1.0490758	total: 6.49s	remaining: 30.1s
# 710:	learn: 1.0490497	total: 6.49s	remaining: 30s
# 711:	learn: 1.0490047	total: 6.5s	remaining: 30s
# 712:	learn: 1.0490022	total: 6.51s	remaining: 30s
# 713:	learn: 1.0489769	total: 6.52s	remaining: 30s
# 714:	learn: 1.0483882	total: 6.53s	remaining: 30s
# 715:	learn: 1.0483572	total: 6.54s	remaining: 30s
# 716:	learn: 1.0478906	total: 6.55s	remaining: 30s
# 717:	learn: 1.0467047	total: 6.56s	remaining: 30s
# 718:	learn: 1.0463019	total: 6.57s	remaining: 30s
# 719:	learn: 1.0462776	total: 6.58s	remaining: 30s
# 720:	learn: 1.0457443	total: 6.59s	remaining: 30s
# 721:	learn: 1.0450346	total: 6.59s	remaining: 29.9s
# 722:	learn: 1.0447726	total: 6.6s	remaining: 29.9s
# 723:	learn: 1.0447313	total: 6.61s	remaining: 29.9s
# 724:	learn: 1.0446981	total: 6.62s	remaining: 29.9s
# 725:	learn: 1.0435938	total: 6.63s	remaining: 29.9s
# 726:	learn: 1.0435641	total: 6.64s	remaining: 29.9s
# 727:	learn: 1.0435125	total: 6.65s	remaining: 29.9s
# 728:	learn: 1.0430830	total: 6.66s	remaining: 29.9s
# 729:	learn: 1.0430422	total: 6.67s	remaining: 29.9s
# 730:	learn: 1.0430155	total: 6.68s	remaining: 29.9s
# 731:	learn: 1.0429924	total: 6.69s	remaining: 29.9s
# 732:	learn: 1.0429670	total: 6.7s	remaining: 29.8s
# 733:	learn: 1.0429447	total: 6.71s	remaining: 29.8s
# 734:	learn: 1.0429424	total: 6.71s	remaining: 29.8s
# 735:	learn: 1.0423104	total: 6.72s	remaining: 29.8s
# 736:	learn: 1.0411424	total: 6.73s	remaining: 29.8s
# 737:	learn: 1.0411401	total: 6.74s	remaining: 29.8s
# 738:	learn: 1.0406709	total: 6.75s	remaining: 29.8s
# 739:	learn: 1.0406451	total: 6.76s	remaining: 29.8s
# 740:	learn: 1.0406233	total: 6.77s	remaining: 29.8s
# 741:	learn: 1.0406166	total: 6.78s	remaining: 29.8s
# 742:	learn: 1.0405854	total: 6.79s	remaining: 29.8s
# 743:	learn: 1.0400500	total: 6.8s	remaining: 29.7s
# 744:	learn: 1.0395107	total: 6.81s	remaining: 29.7s
# 745:	learn: 1.0394858	total: 6.82s	remaining: 29.7s
# 746:	learn: 1.0390933	total: 6.82s	remaining: 29.7s
# 747:	learn: 1.0389894	total: 6.83s	remaining: 29.7s
# 748:	learn: 1.0389872	total: 6.84s	remaining: 29.7s
# 749:	learn: 1.0389635	total: 6.85s	remaining: 29.7s
# 750:	learn: 1.0386344	total: 6.86s	remaining: 29.7s
# 751:	learn: 1.0379135	total: 6.87s	remaining: 29.7s
# 752:	learn: 1.0374821	total: 6.88s	remaining: 29.7s
# 753:	learn: 1.0371371	total: 6.89s	remaining: 29.7s
# 754:	learn: 1.0371140	total: 6.9s	remaining: 29.6s
# 755:	learn: 1.0371120	total: 6.91s	remaining: 29.6s
# 756:	learn: 1.0362075	total: 6.92s	remaining: 29.6s
# 757:	learn: 1.0358281	total: 6.92s	remaining: 29.6s
# 758:	learn: 1.0353908	total: 6.93s	remaining: 29.6s
# 759:	learn: 1.0353683	total: 6.94s	remaining: 29.6s
# 760:	learn: 1.0353663	total: 6.95s	remaining: 29.6s
# 761:	learn: 1.0340919	total: 6.96s	remaining: 29.6s
# 762:	learn: 1.0337178	total: 6.97s	remaining: 29.6s
# 763:	learn: 1.0336958	total: 6.98s	remaining: 29.6s
# 764:	learn: 1.0328291	total: 6.99s	remaining: 29.6s
# 765:	learn: 1.0328271	total: 7s	remaining: 29.5s
# 766:	learn: 1.0328249	total: 7.01s	remaining: 29.5s
# 767:	learn: 1.0328230	total: 7.01s	remaining: 29.5s
# 768:	learn: 1.0328007	total: 7.02s	remaining: 29.5s
# 769:	learn: 1.0327684	total: 7.03s	remaining: 29.5s
# 770:	learn: 1.0327665	total: 7.04s	remaining: 29.5s
# 771:	learn: 1.0319632	total: 7.05s	remaining: 29.5s
# 772:	learn: 1.0314885	total: 7.06s	remaining: 29.5s
# 773:	learn: 1.0314866	total: 7.07s	remaining: 29.5s
# 774:	learn: 1.0314547	total: 7.08s	remaining: 29.5s
# 775:	learn: 1.0304054	total: 7.09s	remaining: 29.4s
# 776:	learn: 1.0301788	total: 7.1s	remaining: 29.4s
# 777:	learn: 1.0301765	total: 7.11s	remaining: 29.4s
# 778:	learn: 1.0298270	total: 7.12s	remaining: 29.4s
# 779:	learn: 1.0298095	total: 7.12s	remaining: 29.4s
# 780:	learn: 1.0294936	total: 7.13s	remaining: 29.4s
# 3786:	learn: 0.3025657	total: 29.1s	remaining: 1.64s
# 3787:	learn: 0.3025657	total: 29.1s	remaining: 1.63s
# 3788:	learn: 0.3025656	total: 29.1s	remaining: 1.62s
# 3789:	learn: 0.3025656	total: 29.1s	remaining: 1.61s
# 3790:	learn: 0.3025656	total: 29.1s	remaining: 1.6s
# 3791:	learn: 0.3025656	total: 29.1s	remaining: 1.6s
# 3792:	learn: 0.3025656	total: 29.1s	remaining: 1.59s
# 3793:	learn: 0.3025655	total: 29.1s	remaining: 1.58s
# 3794:	learn: 0.3025655	total: 29.1s	remaining: 1.57s
# 3795:	learn: 0.3025655	total: 29.2s	remaining: 1.57s
# 3796:	learn: 0.3025655	total: 29.2s	remaining: 1.56s
# 3797:	learn: 0.3025655	total: 29.2s	remaining: 1.55s
# 3798:	learn: 0.3025655	total: 29.2s	remaining: 1.54s
# 3799:	learn: 0.3025655	total: 29.2s	remaining: 1.53s
# 3800:	learn: 0.3025655	total: 29.2s	remaining: 1.53s
# 3801:	learn: 0.3025655	total: 29.2s	remaining: 1.52s
# 3802:	learn: 0.3025655	total: 29.2s	remaining: 1.51s
# 3803:	learn: 0.3025654	total: 29.2s	remaining: 1.5s
# 3804:	learn: 0.3025654	total: 29.2s	remaining: 1.5s
# 3805:	learn: 0.3025654	total: 29.2s	remaining: 1.49s
# 3806:	learn: 0.3025654	total: 29.2s	remaining: 1.48s
# 3807:	learn: 0.3025654	total: 29.2s	remaining: 1.47s
# 3808:	learn: 0.3025653	total: 29.2s	remaining: 1.47s
# 3809:	learn: 0.3025653	total: 29.2s	remaining: 1.46s
# 3810:	learn: 0.3025653	total: 29.3s	remaining: 1.45s
# 3811:	learn: 0.3025653	total: 29.3s	remaining: 1.44s
# 3812:	learn: 0.3025653	total: 29.3s	remaining: 1.44s
# 3813:	learn: 0.3025653	total: 29.3s	remaining: 1.43s
# 3814:	learn: 0.3025653	total: 29.3s	remaining: 1.42s
# 3815:	learn: 0.3025653	total: 29.3s	remaining: 1.41s
# 3816:	learn: 0.3023036	total: 29.3s	remaining: 1.4s
# 3817:	learn: 0.3023035	total: 29.3s	remaining: 1.4s
# 3818:	learn: 0.3023035	total: 29.3s	remaining: 1.39s
# 3819:	learn: 0.3023034	total: 29.3s	remaining: 1.38s
# 3820:	learn: 0.3023034	total: 29.3s	remaining: 1.37s
# 3821:	learn: 0.3023033	total: 29.3s	remaining: 1.37s
# 3822:	learn: 0.3023033	total: 29.3s	remaining: 1.36s
# 3823:	learn: 0.3023033	total: 29.4s	remaining: 1.35s
# 3824:	learn: 0.3023032	total: 29.4s	remaining: 1.34s
# 3825:	learn: 0.3023032	total: 29.4s	remaining: 1.33s
# 3826:	learn: 0.3023031	total: 29.4s	remaining: 1.33s
# 3827:	learn: 0.3023031	total: 29.4s	remaining: 1.32s
# 3828:	learn: 0.3023030	total: 29.4s	remaining: 1.31s
# 3829:	learn: 0.3023030	total: 29.4s	remaining: 1.3s
# 3830:	learn: 0.3023030	total: 29.4s	remaining: 1.3s
# 3831:	learn: 0.3023030	total: 29.4s	remaining: 1.29s
# 3832:	learn: 0.3023030	total: 29.4s	remaining: 1.28s
# 3833:	learn: 0.3023028	total: 29.4s	remaining: 1.27s
# 3834:	learn: 0.3023027	total: 29.4s	remaining: 1.27s
# 3835:	learn: 0.3023027	total: 29.4s	remaining: 1.26s
# 3836:	learn: 0.3023027	total: 29.4s	remaining: 1.25s
# 3837:	learn: 0.3023026	total: 29.4s	remaining: 1.24s
# 3838:	learn: 0.3023026	total: 29.5s	remaining: 1.24s
# 3839:	learn: 0.3023026	total: 29.5s	remaining: 1.23s
# 3840:	learn: 0.3023025	total: 29.5s	remaining: 1.22s
# 3841:	learn: 0.3023025	total: 29.5s	remaining: 1.21s
# 3842:	learn: 0.3023024	total: 29.5s	remaining: 1.2s
# 3843:	learn: 0.3023024	total: 29.5s	remaining: 1.2s
# 3844:	learn: 0.3023024	total: 29.5s	remaining: 1.19s
# 3845:	learn: 0.3023024	total: 29.5s	remaining: 1.18s
# 3846:	learn: 0.3023024	total: 29.5s	remaining: 1.17s
# 3847:	learn: 0.3023024	total: 29.5s	remaining: 1.17s
# 3848:	learn: 0.3023024	total: 29.5s	remaining: 1.16s
# 3849:	learn: 0.3023024	total: 29.5s	remaining: 1.15s
# 3850:	learn: 0.3023024	total: 29.5s	remaining: 1.14s
# 3851:	learn: 0.3023024	total: 29.5s	remaining: 1.14s
# 3852:	learn: 0.3023023	total: 29.6s	remaining: 1.13s
# 3853:	learn: 0.3023023	total: 29.6s	remaining: 1.12s
# 3854:	learn: 0.3023023	total: 29.6s	remaining: 1.11s
# 3855:	learn: 0.3023023	total: 29.6s	remaining: 1.1s
# 3856:	learn: 0.3023023	total: 29.6s	remaining: 1.1s
# 3857:	learn: 0.3023022	total: 29.6s	remaining: 1.09s
# 3858:	learn: 0.3023021	total: 29.6s	remaining: 1.08s
# 3859:	learn: 0.3023021	total: 29.6s	remaining: 1.07s
# 3860:	learn: 0.3023021	total: 29.6s	remaining: 1.06s
# 3861:	learn: 0.3023021	total: 29.6s	remaining: 1.06s
# 3862:	learn: 0.3023021	total: 29.6s	remaining: 1.05s
# 3863:	learn: 0.3023020	total: 29.6s	remaining: 1.04s
# 3864:	learn: 0.3023020	total: 29.6s	remaining: 1.03s
# 3865:	learn: 0.3023020	total: 29.6s	remaining: 1.03s
# 3866:	learn: 0.3023020	total: 29.6s	remaining: 1.02s
# 3867:	learn: 0.3023019	total: 29.7s	remaining: 1.01s
# 3868:	learn: 0.3023019	total: 29.7s	remaining: 1s
# 3869:	learn: 0.3023019	total: 29.7s	remaining: 997ms
# 3870:	learn: 0.3023019	total: 29.7s	remaining: 989ms
# 3871:	learn: 0.3023018	total: 29.7s	remaining: 981ms
# 3872:	learn: 0.3023016	total: 29.7s	remaining: 974ms
# 3873:	learn: 0.3023016	total: 29.7s	remaining: 966ms
# 3874:	learn: 0.3023016	total: 29.7s	remaining: 958ms
# 3875:	learn: 0.3023016	total: 29.7s	remaining: 951ms
# 3876:	learn: 0.3023016	total: 29.7s	remaining: 943ms
# 3972:	learn: 0.3022998	total: 30.4s	remaining: 206ms
# 3973:	learn: 0.3022998	total: 30.4s	remaining: 199ms
# 3974:	learn: 0.3022998	total: 30.4s	remaining: 191ms
# 3975:	learn: 0.3022998	total: 30.4s	remaining: 184ms
# 3976:	learn: 0.3022997	total: 30.4s	remaining: 176ms
# 3977:	learn: 0.3022997	total: 30.4s	remaining: 168ms
# 3978:	learn: 0.3022997	total: 30.4s	remaining: 161ms
# 3979:	learn: 0.3022997	total: 30.4s	remaining: 153ms
# 3980:	learn: 0.3022997	total: 30.4s	remaining: 145ms
# 3981:	learn: 0.3022997	total: 30.4s	remaining: 138ms
# 3982:	learn: 0.3022997	total: 30.4s	remaining: 130ms
# 3983:	learn: 0.3022997	total: 30.5s	remaining: 122ms
# 3984:	learn: 0.3022997	total: 30.5s	remaining: 115ms
# 3985:	learn: 0.3022997	total: 30.5s	remaining: 107ms
# 3986:	learn: 0.3022997	total: 30.5s	remaining: 99.4ms
# 3987:	learn: 0.3022996	total: 30.5s	remaining: 91.7ms
# 3988:	learn: 0.3022996	total: 30.5s	remaining: 84.1ms
# 3989:	learn: 0.3022996	total: 30.5s	remaining: 76.4ms
# 3990:	learn: 0.3022996	total: 30.5s	remaining: 68.8ms
# 3991:	learn: 0.3022996	total: 30.5s	remaining: 61.1ms
# 3992:	learn: 0.3022996	total: 30.5s	remaining: 53.5ms
# 3993:	learn: 0.3022996	total: 30.5s	remaining: 45.9ms
# 3994:	learn: 0.3022995	total: 30.5s	remaining: 38.2ms
# 3995:	learn: 0.3022995	total: 30.5s	remaining: 30.6ms
# 3996:	learn: 0.3022995	total: 30.5s	remaining: 22.9ms
# 3997:	learn: 0.3022995	total: 30.6s	remaining: 15.3ms
# 3998:	learn: 0.3022994	total: 30.6s	remaining: 7.64ms
# 3999:	learn: 0.3022994	total: 30.6s	remaining: 0us

# %%
print(scores)
# Out:
# [462.3104897700519, 458.93940915316733, 503.12773928773834, 434.62804135338365]

# %% [markdown]
# [0.3706618248854376, 0.4875355331238526, 0.6506005719809389, 0.07157820889607548]

# %%
df = pd.DataFrame()
check = set()
for i in rf_forecasts_dict_LR:
    frcst_for_well_l_r = pd.DataFrame()
    frcst_for_well_w_c = pd.DataFrame()
    
    frcst_for_well_l_r['MEASURED_IN_DATE'] = rf_forecasts_dict_LR[i].index
    frcst_for_well_w_c['MEASURED_IN_DATE'] = cb_forecasts_dict_WC[i].index
    
    frcst_for_well_l_r['WELL_NAME'] = i
    frcst_for_well_w_c['WELL_NAME'] = i
    
    frcst_for_well_w_c = frcst_for_well_w_c.set_index('MEASURED_IN_DATE')
    frcst_for_well_l_r = frcst_for_well_l_r.set_index('MEASURED_IN_DATE')
    
    frcst_for_well_l_r['LIQ_RATE'] = rf_forecasts_dict_LR[i]
    frcst_for_well_w_c['WATER_CUT'] = cb_forecasts_dict_WC[i]
    
    frcst_for_well = frcst_for_well_l_r.merge(frcst_for_well_w_c
                                              , on=['MEASURED_IN_DATE', 'WELL_NAME']
                                              , how='inner')
    if i not in check:
        check.add(i)
    else:
        print(i)
    df = pd.concat([df, frcst_for_well])
df = df.reset_index()
df.head()
# Out:
#   MEASURED_IN_DATE                                          WELL_NAME  \
# 0       2022-01-20  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# 1       2022-01-21  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# 2       2022-01-22  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# 3       2022-01-23  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# 4       2022-01-24  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
#
#      LIQ_RATE  WATER_CUT
# 0  434.912428  90.101609
# 1  434.048899  91.401233
# 2  433.362593  91.245552
# 3  430.958546  91.237029
# 4  428.949426  91.095173

# %%
pogodite_eto_realno = pd.concat([df, answer])
pogodite_eto_realno
# Out:
#     MEASURED_IN_DATE                                          WELL_NAME  \
# 0         2022-01-20  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# 1         2022-01-21  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# 2         2022-01-22  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# 3         2022-01-23  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# 4         2022-01-24  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# ..               ...                                                ...
# 117       2022-09-26  fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
# 118       2022-09-27  fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
# 119       2022-09-28  fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
# 120       2022-09-29  fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
# 121       2022-09-30  fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
#
#        LIQ_RATE  WATER_CUT
# 0    434.912428  90.101609
# 1    434.048899  91.401233
# 2    433.362593  91.245552
# 3    430.958546  91.237029
# 4    428.949426  91.095173
# ..          ...        ...
# 117  475.516724  41.833595
# 118  475.007874  41.851025
# 119  474.552460  41.868034
# 120  474.178833  41.884644
# 121  473.892853  41.900875
#
# [22410 rows x 4 columns]

# %%
sampl_sab = sampl_sab.drop(columns=['LIQ_RATE', 'WATER_CUT'])
sampl_sab['MEASURED_IN_DATE'] = pd.to_datetime(sampl_sab['MEASURED_IN_DATE'])

# %%
pogodite_eto_realno.merge(sampl_sab, on=['WELL_NAME', 'MEASURED_IN_DATE'], how='inner')
# Out:
#       MEASURED_IN_DATE                                          WELL_NAME  \
# 0           2022-06-12  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# 1           2022-06-13  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# 2           2022-06-14  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# 3           2022-06-15  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# 4           2022-06-16  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# ...                ...                                                ...
# 20661       2022-09-24  fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
# 20662       2022-09-25  fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
# 20663       2022-09-26  fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
# 20664       2022-09-27  fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
# 20665       2022-09-28  fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
#
#          LIQ_RATE  WATER_CUT
# 0      425.943736  90.907732
# 1      425.943736  90.907732
# 2      425.943736  90.907732
# 3      425.943736  90.907732
# 4      425.943736  90.907732
# ...           ...        ...
# 20661  476.409393  41.797318
# 20662  476.016968  41.815704
# 20663  475.516724  41.833595
# 20664  475.007874  41.851025
# 20665  474.552460  41.868034
#
# [20666 rows x 4 columns]

# %%
pogodite_eto_realno.to_csv('blyat_gde_rijuliya_bez_tebya_ya_ne_mogu_jit.csv')
