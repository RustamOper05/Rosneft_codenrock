# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit, RandomizedSearchCV
from sklearn.metrics import mean_squared_error
from catboost import CatBoostRegressor


train_data = pd.read_csv('rosneft/train_data.csv')
gtm = pd.read_csv('rosneft/gtm.csv')
coords = pd.read_csv('rosneft/coords.csv')
sampl_sab = pd.read_csv('rosneft/sample_submission.csv')
train_data["MEASURED_IN_DATE"] = pd.to_datetime(train_data["MEASURED_IN_DATE"])


# all_data = pd.read_csv('rosneft/gotov_ebat.csv', index_col='Unnamed: 0')
all_data = pd.read_csv('rosneft/gotov_ebat.csv', index_col='Unnamed: 0')
all_data["MEASURED_IN_DATE"] = pd.to_datetime(all_data["MEASURED_IN_DATE"])
all_data_w_d = all_data.drop(columns=['MEASURED_IN_DATE'])

# %%
all_data
# Out:
#        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT   P_ZAB  INTAKE  \
# 17437        2016-08-02       0.0     690.0        0.5  159.19     0.0
# 17438        2016-08-03       0.0     690.0        0.5  159.19     0.0
# 17439        2016-08-04       0.0     690.0        0.5  153.19     0.0
# 17440        2016-08-05       0.0     780.0        0.5  151.21     0.0
# 17441        2016-08-06       0.0     780.0        0.5  151.21     0.0
# ...                 ...       ...       ...        ...     ...     ...
# 104377       2022-05-31       0.0     339.0       70.0   55.69     0.0
# 53662        2022-05-31       0.0     225.0       58.0   75.48     0.0
# 54379        2022-05-31       0.0     170.0       91.0  178.15     0.0
# 104892       2022-05-31       0.0     208.0       88.0  113.02     0.0
# 122411       2022-05-31       0.0     328.0       70.0   60.73     0.0
#
#                                                 WELL_NAME  time_id
# 17437   aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...        0
# 17438   aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...        1
# 17439   aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...        2
# 17440   aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...        3
# 17441   aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...        4
# ...                                                   ...      ...
# 104377  18ea8ca26bcabaac4fd073a00ba741a627f3649a6983a7...     2128
# 53662   b04d54ff8a670262e81f0e0b514a32e03baa85200cd9f2...     2128
# 54379   b694e479af091b82198c24a43195efbb9578a4f0e2e163...     2128
# 104892  139e20fe864acf1a4b831ac25d417fe70725cbee85197c...     2128
# 122411  1de41569155b66df7355c8fc7a53e80333aea79dc9bb37...     2128
#
# [122412 rows x 8 columns]

# %%
def predict_step_by_step(model, row, days):
    forecasting_for_days = []
    new_arr_to_predict = row.to_numpy().tolist()
    for i in range(days):
        tensor_to_predict = np.array(new_arr_to_predict)

        predict = model.predict(tensor_to_predict)[0]
        forecasting_for_days.append(predict)
        new_arr_to_predict = [new_arr_to_predict[0][:-1]]
        new_arr_to_predict[0].insert(0, forecasting_for_days[-1])
    
    return forecasting_for_days

def lag_features_liquid_rate(df, lags):
    for lag in lags:
        df[f"lag_t-{lag}"] = df.groupby(["CHARWORK"])["LIQ_RATE"].transform(
            lambda x: x.shift(lag))
    return df

def lag_features_water_cut(df, lags):
    for lag in lags:
        df[f"lag_t-{lag}"] = df.groupby(["CHARWORK"])["WATER_CUT"].transform(
            lambda x: x.shift(lag))
    return df

# %%
def get_rf_cb_predictions(DATA_DIR, LAG_WINDOW_SIZE = 90) -> pd.DataFrame:

    all_data = pd.read_csv(DATA_DIR + '/gotov_ebat.csv')
    all_data["MEASURED_IN_DATE"] = pd.to_datetime(all_data["MEASURED_IN_DATE"])
    to_drop = ['P_ZAB', 'INTAKE', 'Unnamed: 0', 'time_id']
    all_data = all_data.drop(columns=to_drop)


    rf_to_do_dict = {
        'debcf7a160692239563af8a9c8ba32c4ba067e747f19c8073055e2be5aeb4022': 253,
         '114183900f2d540609911971f3ae3f3d42ab8b4fa9252d0c4076b00d482c1594': 216,
         '8d4b4b4f0140179b1c94722f3d39100bcde8f3c39415983813c74bd52cf1ab3c': 336,
         '2ceb0e2b3c28cc1b3c3f8dec7ad56148dbf6ea77f9ffc832f4c4b9ce845d9bb7': 133
    }

    rf_date_miss_dict = {
        key: all_data[all_data.WELL_NAME == key] \
        for key in rf_to_do_dict.keys()
    }
    
    
    rf_forecasts_dict_WC = dict()
    best_wc_models = []

    for c, i in enumerate(rf_date_miss_dict):
        train_data = rf_date_miss_dict[i].drop(columns=['WELL_NAME', 'LIQ_RATE'])
        train_with_lags = lag_features_water_cut(train_data, lags=[*range(1, LAG_WINDOW_SIZE + 1)])
        train_with_lags = train_with_lags.dropna()
        y = train_with_lags['WATER_CUT']
        if len(train_with_lags['MEASURED_IN_DATE']) == 0:
            continue
        else:
            last_date = np.array(train_with_lags['MEASURED_IN_DATE'])[-1]
            train_with_lags = train_with_lags.drop(columns=['WATER_CUT', 'CHARWORK'
                                                            , 'MEASURED_IN_DATE'])
            index_to_predict = pd.date_range(start=last_date + np.timedelta64(1, 'D')
                                             , end=last_date + np.timedelta64(rf_to_do_dict[i], 'D'))
            model = RandomForestRegressor(n_estimators=110, min_samples_split=5
                                          , min_samples_leaf=3, random_state=1984)        
            model.fit(train_with_lags, y)
            forecast = pd.Series(predict_step_by_step(model, train_with_lags.tail(1)
                                                      , rf_to_do_dict[i])
                                 , index=index_to_predict)
            rf_forecasts_dict_WC[i] = forecast
#             print('Score:\t', mean_squared_error(model.predict(train_with_lags), y))
    
    
    def drop_constant_columns(df):
        return df.loc[:, (df != df.iloc[0]).any()]


    cb_forecasts_dict_LR = dict()
    # best_wc_cbrs = []
    scores = []


    rf_forecasts_dict_LR = dict()
    # best_lr_models = []

    for c, i in enumerate(rf_date_miss_dict):
        train_data = rf_date_miss_dict[i].drop(columns=['WELL_NAME', 'WATER_CUT'])
        train_with_lags = lag_features_liquid_rate(train_data
                                                   , lags=[*range(1, LAG_WINDOW_SIZE + 1)])
        train_with_lags = train_with_lags.dropna()
        y = train_with_lags['LIQ_RATE']
        if len(train_with_lags['MEASURED_IN_DATE']) == 0:
            continue
        else:
            last_date = np.array(train_with_lags['MEASURED_IN_DATE'])[-1]
            train_with_lags = train_with_lags.drop(columns=['LIQ_RATE'
                                                            , 'MEASURED_IN_DATE', 'CHARWORK'])
            index_to_predict = pd.date_range(start=last_date + np.timedelta64(1, 'D')
                                             , end=last_date \
                                             + np.timedelta64(rf_to_do_dict[i], 'D'))

            model = CatBoostRegressor(iterations=1400, learning_rate=7e-3
                                              , max_depth=10, random_state=1984)
            model.fit(train_with_lags, y, metric_period=200)
            forecast = pd.Series(predict_step_by_step(model, train_with_lags.tail(1)
                                                      , rf_to_do_dict[i])
                                 , index=index_to_predict)
            cb_forecasts_dict_LR[i] = forecast
            scores.append(mean_squared_error(model.predict(train_with_lags), y))
    #         best__cbrs.append(search.best_estimator_)
    
    df = pd.DataFrame()
    check = set()
    for i in rf_forecasts_dict_WC:
        frcst_for_well_l_r = pd.DataFrame()
        frcst_for_well_w_c = pd.DataFrame()

        frcst_for_well_w_c['MEASURED_IN_DATE'] = rf_forecasts_dict_WC[i].index
        frcst_for_well_l_r['MEASURED_IN_DATE'] = cb_forecasts_dict_LR[i].index
        frcst_for_well_w_c['WELL_NAME'] = i
        frcst_for_well_l_r['WELL_NAME'] = i
        frcst_for_well_w_c = frcst_for_well_w_c.set_index('MEASURED_IN_DATE')
        frcst_for_well_l_r = frcst_for_well_l_r.set_index('MEASURED_IN_DATE')
        frcst_for_well_l_r['LIQ_RATE'] = cb_forecasts_dict_LR[i]
        frcst_for_well_w_c['WATER_CUT'] = rf_forecasts_dict_WC[i]
        frcst_for_well = frcst_for_well_l_r.merge(frcst_for_well_w_c
                                                  , on=['MEASURED_IN_DATE', 'WELL_NAME']
                                                  , how='inner')
        if i not in check:
            check.add(i)
        else:
            print(i)
        df = pd.concat([df, frcst_for_well])
    df = df.reset_index()
    
    return df

# %%
def get_rf_cb_predictions(DATA_DIR, LAG_WINDOW_SIZE = 90) -> pd.DataFrame:

    all_data = pd.read_csv(DATA_DIR + '/gotov_ebat.csv')
    all_data["MEASURED_IN_DATE"] = pd.to_datetime(all_data["MEASURED_IN_DATE"])
    to_drop = ['P_ZAB', 'INTAKE', 'Unnamed: 0', 'time_id']
    all_data = all_data.drop(columns=to_drop)

    # I HATE NIG-
    rf_to_do_dict = {
        'debcf7a160692239563af8a9c8ba32c4ba067e747f19c8073055e2be5aeb4022': 253,
         '114183900f2d540609911971f3ae3f3d42ab8b4fa9252d0c4076b00d482c1594': 216,
         '8d4b4b4f0140179b1c94722f3d39100bcde8f3c39415983813c74bd52cf1ab3c': 336,
         '2ceb0e2b3c28cc1b3c3f8dec7ad56148dbf6ea77f9ffc832f4c4b9ce845d9bb7': 133
    }

    rf_date_miss_dict = {
        key: all_data[all_data.WELL_NAME == key] \
        for key in rf_to_do_dict.keys()
    }
    rf_forecasts_dict_WC = dict()
    best_wc_models = []
    for c, i in enumerate(rf_date_miss_dict):
        train_data = rf_date_miss_dict[i].drop(columns=['WELL_NAME', 'LIQ_RATE'])
        train_with_lags = lag_features_water_cut(train_data, lags=[*range(1, LAG_WINDOW_SIZE + 1)])
        train_with_lags = train_with_lags.dropna()
        y = train_with_lags['WATER_CUT']
        if len(train_with_lags['MEASURED_IN_DATE']) == 0:
            continue
        else:
            last_date = np.array(train_with_lags['MEASURED_IN_DATE'])[-1]
            train_with_lags = train_with_lags.drop(columns=['WATER_CUT', 'CHARWORK'
                                                            , 'MEASURED_IN_DATE'])
            index_to_predict = pd.date_range(start=last_date + np.timedelta64(1, 'D')
                                             , end=last_date + np.timedelta64(rf_to_do_dict[i], 'D'))
            model = RandomForestRegressor(n_estimators=110, min_samples_split=5
                                          , min_samples_leaf=3, random_state=1984)        
            model.fit(train_with_lags, y)
            forecast = pd.Series(predict_step_by_step(model, train_with_lags.tail(1)
                                                      , rf_to_do_dict[i])
                                 , index=index_to_predict)
            rf_forecasts_dict_WC[i] = forecast
#             print('Score:\t', mean_squared_error(model.predict(train_with_lags), y))
    
    
    def drop_constant_columns(df):
        return df.loc[:, (df != df.iloc[0]).any()]


    cb_forecasts_dict_LR = dict()
    # best_wc_cbrs = []
    scores = []
    rf_forecasts_dict_LR = dict()
    # best_lr_models = []

    for c, i in enumerate(rf_date_miss_dict):
        train_data = rf_date_miss_dict[i].drop(columns=['WELL_NAME', 'WATER_CUT'])
        train_with_lags = lag_features_liquid_rate(train_data
                                                   , lags=[*range(1, LAG_WINDOW_SIZE + 1)])
        train_with_lags = train_with_lags.dropna()
        y = train_with_lags['LIQ_RATE']
        if len(train_with_lags['MEASURED_IN_DATE']) == 0:
            continue
        else:
            last_date = np.array(train_with_lags['MEASURED_IN_DATE'])[-1]
            train_with_lags = train_with_lags.drop(columns=['LIQ_RATE'
                                                            , 'MEASURED_IN_DATE', 'CHARWORK'])
            index_to_predict = pd.date_range(start=last_date + np.timedelta64(1, 'D')
                                             , end=last_date \
                                             + np.timedelta64(rf_to_do_dict[i], 'D'))

            model = CatBoostRegressor(iterations=1400, learning_rate=7e-3
                                              , max_depth=10, random_state=1984)
            model.fit(train_with_lags, y, metric_period=200)
            forecast = pd.Series(predict_step_by_step(model, train_with_lags.tail(1)
                                                      , rf_to_do_dict[i])
                                 , index=index_to_predict)
            cb_forecasts_dict_LR[i] = forecast
            scores.append(mean_squared_error(model.predict(train_with_lags), y))
    #         best__cbrs.append(search.best_estimator_)
    
    
    df = pd.DataFrame()
    check = set()
    for i in rf_forecasts_dict_WC:
        frcst_for_well_l_r = pd.DataFrame()
        frcst_for_well_w_c = pd.DataFrame()
        frcst_for_well_w_c['MEASURED_IN_DATE'] = rf_forecasts_dict_WC[i].index
        frcst_for_well_l_r['MEASURED_IN_DATE'] = cb_forecasts_dict_LR[i].index
        frcst_for_well_w_c['WELL_NAME'] = i
        frcst_for_well_l_r['WELL_NAME'] = i
        frcst_for_well_w_c = frcst_for_well_w_c.set_index('MEASURED_IN_DATE')
        frcst_for_well_l_r = frcst_for_well_l_r.set_index('MEASURED_IN_DATE')
        frcst_for_well_l_r['LIQ_RATE'] = cb_forecasts_dict_LR[i]
        frcst_for_well_w_c['WATER_CUT'] = rf_forecasts_dict_WC[i]
        frcst_for_well = frcst_for_well_l_r.merge(frcst_for_well_w_c
                                                  , on=['MEASURED_IN_DATE', 'WELL_NAME']
                                                  , how='inner')
        if i not in check:
            check.add(i)
        else:
            print(i)
        df = pd.concat([df, frcst_for_well])
    df = df.reset_index()
    
    return df
# Out:
# 0:	learn: 40.7446887	total: 32.9ms	remaining: 46s
# 200:	learn: 13.4435697	total: 6.7s	remaining: 40s
# 400:	learn: 6.5421804	total: 13.6s	remaining: 34s
# 600:	learn: 4.8979563	total: 20.4s	remaining: 27.2s
# 800:	learn: 4.3135647	total: 27.9s	remaining: 20.9s
# 1000:	learn: 3.9644037	total: 35.9s	remaining: 14.3s
# 1200:	learn: 3.7153399	total: 43.5s	remaining: 7.21s
# 1399:	learn: 3.4747430	total: 51.4s	remaining: 0us
# 0:	learn: 23.6993047	total: 1.17ms	remaining: 1.64s
# 200:	learn: 12.5519917	total: 772ms	remaining: 4.61s
# 400:	learn: 7.7439892	total: 1.53s	remaining: 3.82s
# 600:	learn: 5.4028542	total: 2.38s	remaining: 3.16s
# 800:	learn: 4.0690680	total: 3.2s	remaining: 2.39s
# 1000:	learn: 3.1803532	total: 3.95s	remaining: 1.57s
# 1200:	learn: 2.5718623	total: 4.66s	remaining: 772ms
# 1399:	learn: 2.1601799	total: 5.38s	remaining: 0us
# 0:	learn: 38.6801650	total: 1.05ms	remaining: 1.47s
# 200:	learn: 16.5448036	total: 669ms	remaining: 3.99s
# 400:	learn: 7.5175734	total: 1.34s	remaining: 3.35s
# 600:	learn: 3.8958621	total: 2s	remaining: 2.67s
# 800:	learn: 2.3745548	total: 2.66s	remaining: 1.99s
# 1000:	learn: 1.6024899	total: 3.39s	remaining: 1.35s
# 1200:	learn: 1.1639076	total: 4.16s	remaining: 690ms
# 1399:	learn: 0.8646765	total: 4.89s	remaining: 0us
# 0:	learn: 15.9645683	total: 4.05ms	remaining: 5.67s
# 200:	learn: 5.9603983	total: 810ms	remaining: 4.83s
# 400:	learn: 2.7759946	total: 1.68s	remaining: 4.18s
# 600:	learn: 1.7266339	total: 2.53s	remaining: 3.36s
# 800:	learn: 1.2519272	total: 3.37s	remaining: 2.52s
# 1000:	learn: 0.9851696	total: 4.22s	remaining: 1.68s
# 1200:	learn: 0.8169981	total: 5.07s	remaining: 840ms
# 1399:	learn: 0.6743405	total: 5.96s	remaining: 0us
#     MEASURED_IN_DATE                                          WELL_NAME  \
# 0         2022-01-20  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# 1         2022-01-21  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# 2         2022-01-22  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# 3         2022-01-23  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# 4         2022-01-24  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
# ..               ...                                                ...
# 933       2022-09-25  2ceb0e2b3c28cc1b3c3f8dec7ad56148dbf6ea77f9ffc8...
# 934       2022-09-26  2ceb0e2b3c28cc1b3c3f8dec7ad56148dbf6ea77f9ffc8...
# 935       2022-09-27  2ceb0e2b3c28cc1b3c3f8dec7ad56148dbf6ea77f9ffc8...
# 936       2022-09-28  2ceb0e2b3c28cc1b3c3f8dec7ad56148dbf6ea77f9ffc8...
# 937       2022-09-29  2ceb0e2b3c28cc1b3c3f8dec7ad56148dbf6ea77f9ffc8...
#
#        LIQ_RATE  WATER_CUT
# 0    435.535228  90.511002
# 1    434.564190  90.502407
# 2    434.619615  90.531591
# 3    433.021415  90.550742
# 4    431.159840  90.579024
# ..          ...        ...
# 933   90.705456   7.545065
# 934   90.687178   7.545065
# 935   90.659510   7.545065
# 936   90.721293   7.545065
# 937   90.711585   7.545065
#
# [938 rows x 4 columns]

# %%
all_data = pd.read_csv('rosneft/gotov_ebat.csv')
all_data["MEASURED_IN_DATE"] = pd.to_datetime(all_data["MEASURED_IN_DATE"])
to_drop = ['P_ZAB', 'INTAKE', 'Unnamed: 0', 'time_id']
all_data = all_data.drop(columns=to_drop)

rf_date_miss_dict = dict()
for i in all_data.WELL_NAME.unique():
    rf_date_miss_dict[i] = all_data[all_data['WELL_NAME'] == i]
# rf_date_miss_dict

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

def vaildate_timeseries(data, y, model):
    X = data[:len(data)-20]
    y_true = y[len(data)-20:]
    forecast = pd.Series(predict_step_by_step(model, X, 20))
    
    return mean_absolute_error(forecast, y_true)

def rijilya_predict(LAG_WINDOW_SIZE=60, forecast_horizon=336) -> pd.DataFrame:    
    rf_forecasts_dict_WC = dict()
    rf_forecasts_dict_LR = dict()
    for c, i in enumerate(rf_date_miss_dict):
        print(i)
        train_data = rf_date_miss_dict[i].drop(columns=['WELL_NAME', 'LIQ_RATE'])
        train_with_lags = lag_features_water_cut(train_data, lags=[*range(1, LAG_WINDOW_SIZE + 1)])
        train_with_lags = train_with_lags.dropna()
        y = train_with_lags['WATER_CUT']
        if len(y) == 0:
            continue
        last_date = np.array(train_with_lags['MEASURED_IN_DATE'])[-1]
        index_to_predict = pd.date_range(start=last_date + np.timedelta64(1, 'D'), end=last_date + np.timedelta64(forecast_horizon, 'D'))
        train_with_lags = train_with_lags.drop(columns=['WATER_CUT', 'CHARWORK', 'MEASURED_IN_DATE'])
        model = RandomForestRegressor(n_estimators=110, min_samples_split=5, min_samples_leaf=3, random_state=2077)        
        model.fit(train_with_lags, y)
        forecast = pd.Series(predict_step_by_step(model, train_with_lags.tail(1), forecast_horizon), index=index_to_predict)
        rf_forecasts_dict_WC[i] = forecast
        print("validate on LR", vaildate_timeseries(train_with_lags, y, model))
        
        train_data = rf_date_miss_dict[i].drop(columns=['WELL_NAME', 'WATER_CUT'])
        train_with_lags = lag_features_liquid_rate(train_data, lags=[*range(1, LAG_WINDOW_SIZE + 1)])
        train_with_lags = train_with_lags.dropna()
        y = train_with_lags['LIQ_RATE']
        train_with_lags = train_with_lags.drop(columns=['LIQ_RATE', 'MEASURED_IN_DATE', 'CHARWORK'])
        model = RandomForestRegressor(n_estimators=110, min_samples_split=5, min_samples_leaf=3, random_state=2077)        
        model.fit(train_with_lags, y)
        print("validate on WC", vaildate_timeseries(train_with_lags, y, model))
        forecast = pd.Series(predict_step_by_step(model, train_with_lags.tail(1), forecast_horizon), index=index_to_predict)
        rf_forecasts_dict_LR[i] = forecast
        
        return rf_forecasts_dict_LR, rf_forecasts_dict_WC

# %%
rijilya_predict()
# Out:
# {'aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac29b1ac755b9a9b31cb8':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  0            2016-08-02       0.0     690.0        0.5
#  1            2016-08-03       0.0     690.0        0.5
#  2            2016-08-04       0.0     690.0        0.5
#  3            2016-08-05       0.0     780.0        0.5
#  4            2016-08-06       0.0     780.0        0.5
#  ...                 ...       ...       ...        ...
#  121664       2022-05-27       0.0     758.0       92.0
#  121748       2022-05-28       0.0     758.0       92.0
#  122032       2022-05-29       0.0     758.0       92.0
#  122174       2022-05-30       0.0     758.0       92.0
#  122369       2022-05-31       0.0     758.0       92.0
#
#                                                  WELL_NAME
#  0       aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...
#  1       aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...
#  2       aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...
#  3       aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...
#  4       aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...
#  ...                                                   ...
#  121664  aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...
#  121748  aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...
#  122032  aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...
#  122174  aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...
#  122369  aebc60b8446bd0a77ff9f51006a8d675f29b1a90d5fac2...
#
#  [2112 rows x 5 columns],
#  '220464bc65a012f767aa51f72f0aadcb3e5ddab2f848ae670fcfffdcff912ec4':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  149          2016-12-29       0.0     455.0        1.0
#  152          2016-12-30       0.0     453.0        1.0
#  153          2016-12-31       0.0     453.0        1.0
#  155          2017-01-01       0.0     453.0        1.0
#  158          2017-01-02       0.0     453.0        1.0
#  ...                 ...       ...       ...        ...
#  121633       2022-05-27       0.0     308.0        7.0
#  121846       2022-05-28       0.0     308.0        7.0
#  121987       2022-05-29       0.0     308.0        7.0
#  122238       2022-05-30       0.0     312.0        7.0
#  122362       2022-05-31       0.0     312.0        7.0
#
#                                                  WELL_NAME
#  149     220464bc65a012f767aa51f72f0aadcb3e5ddab2f848ae...
#  152     220464bc65a012f767aa51f72f0aadcb3e5ddab2f848ae...
#  153     220464bc65a012f767aa51f72f0aadcb3e5ddab2f848ae...
#  155     220464bc65a012f767aa51f72f0aadcb3e5ddab2f848ae...
#  158     220464bc65a012f767aa51f72f0aadcb3e5ddab2f848ae...
#  ...                                                   ...
#  121633  220464bc65a012f767aa51f72f0aadcb3e5ddab2f848ae...
#  121846  220464bc65a012f767aa51f72f0aadcb3e5ddab2f848ae...
#  121987  220464bc65a012f767aa51f72f0aadcb3e5ddab2f848ae...
#  122238  220464bc65a012f767aa51f72f0aadcb3e5ddab2f848ae...
#  122362  220464bc65a012f767aa51f72f0aadcb3e5ddab2f848ae...
#
#  [1961 rows x 5 columns],
#  '4c7a28b12601be8c51bcd4be8b9227a465dfde2e79998f0a0682966705df9a2e':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  238          2017-02-11       0.0    1058.0        7.0
#  241          2017-02-12       0.0    1058.0        7.0
#  244          2017-02-13       0.0    1022.0        7.0
#  247          2017-02-14       0.0    1022.0        7.0
#  251          2017-02-15       0.0    1022.0        8.0
#  ...                 ...       ...       ...        ...
#  121672       2022-05-27       0.0      63.0       38.0
#  121783       2022-05-28       0.0      63.0       38.0
#  122058       2022-05-29       0.0      63.0       38.0
#  122260       2022-05-30       0.0      63.0       38.0
#  122370       2022-05-31       0.0      63.0       38.0
#
#                                                  WELL_NAME
#  238     4c7a28b12601be8c51bcd4be8b9227a465dfde2e79998f...
#  241     4c7a28b12601be8c51bcd4be8b9227a465dfde2e79998f...
#  244     4c7a28b12601be8c51bcd4be8b9227a465dfde2e79998f...
#  247     4c7a28b12601be8c51bcd4be8b9227a465dfde2e79998f...
#  251     4c7a28b12601be8c51bcd4be8b9227a465dfde2e79998f...
#  ...                                                   ...
#  121672  4c7a28b12601be8c51bcd4be8b9227a465dfde2e79998f...
#  121783  4c7a28b12601be8c51bcd4be8b9227a465dfde2e79998f...
#  122058  4c7a28b12601be8c51bcd4be8b9227a465dfde2e79998f...
#  122260  4c7a28b12601be8c51bcd4be8b9227a465dfde2e79998f...
#  122370  4c7a28b12601be8c51bcd4be8b9227a465dfde2e79998f...
#
#  [1931 rows x 5 columns],
#  'e01e3e8c387e0c7c7357753f5e5b23397f66aa04a76cc557e1a7c4a6ba0065c5':        MEASURED_IN_DATE  CHARWORK     LIQ_RATE  WATER_CUT  \
#  459          2017-04-26       0.0  1346.000000   2.000000
#  463          2017-04-27       0.0  1361.000000   2.000000
#  467          2017-04-28       0.0  1361.000000   2.000000
#  470          2017-04-29       0.0  1361.000000   1.000000
#  474          2017-04-30       0.0  1361.000000   1.000000
#  ...                 ...       ...          ...        ...
#  121563       2022-05-27       0.0   897.897959  58.612245
#  121756       2022-05-28       0.0   872.000000  62.000000
#  122069       2022-05-29       0.0   872.000000  62.000000
#  122153       2022-05-30       0.0   872.000000  62.000000
#  122359       2022-05-31       0.0   872.000000  62.000000
#
#                                                  WELL_NAME
#  459     e01e3e8c387e0c7c7357753f5e5b23397f66aa04a76cc5...
#  463     e01e3e8c387e0c7c7357753f5e5b23397f66aa04a76cc5...
#  467     e01e3e8c387e0c7c7357753f5e5b23397f66aa04a76cc5...
#  470     e01e3e8c387e0c7c7357753f5e5b23397f66aa04a76cc5...
#  474     e01e3e8c387e0c7c7357753f5e5b23397f66aa04a76cc5...
#  ...                                                   ...
#  121563  e01e3e8c387e0c7c7357753f5e5b23397f66aa04a76cc5...
#  121756  e01e3e8c387e0c7c7357753f5e5b23397f66aa04a76cc5...
#  122069  e01e3e8c387e0c7c7357753f5e5b23397f66aa04a76cc5...
#  122153  e01e3e8c387e0c7c7357753f5e5b23397f66aa04a76cc5...
#  122359  e01e3e8c387e0c7c7357753f5e5b23397f66aa04a76cc5...
#
#  [1842 rows x 5 columns],
#  '8fd2d65accab0dab1681e687dade3a4260a8bec03b8626f29cfeeef4169ae10f':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  582          2017-05-26       0.0     818.0        1.0
#  583          2017-05-27       0.0     825.0        1.0
#  588          2017-05-28       0.0     813.0        1.0
#  596          2017-05-29       0.0     803.0        1.0
#  599          2017-05-30       0.0     799.0        1.0
#  ...                 ...       ...       ...        ...
#  121690       2022-05-27       0.0     480.0       90.0
#  121742       2022-05-28       0.0     480.0       90.0
#  122075       2022-05-29       0.0     480.0       90.0
#  122190       2022-05-30       0.0     480.0       90.0
#  122374       2022-05-31       0.0     480.0       90.0
#
#                                                  WELL_NAME
#  582     8fd2d65accab0dab1681e687dade3a4260a8bec03b8626...
#  583     8fd2d65accab0dab1681e687dade3a4260a8bec03b8626...
#  588     8fd2d65accab0dab1681e687dade3a4260a8bec03b8626...
#  596     8fd2d65accab0dab1681e687dade3a4260a8bec03b8626...
#  599     8fd2d65accab0dab1681e687dade3a4260a8bec03b8626...
#  ...                                                   ...
#  121690  8fd2d65accab0dab1681e687dade3a4260a8bec03b8626...
#  121742  8fd2d65accab0dab1681e687dade3a4260a8bec03b8626...
#  122075  8fd2d65accab0dab1681e687dade3a4260a8bec03b8626...
#  122190  8fd2d65accab0dab1681e687dade3a4260a8bec03b8626...
#  122374  8fd2d65accab0dab1681e687dade3a4260a8bec03b8626...
#
#  [1822 rows x 5 columns],
#  'fb40f51a63a63fb7fbdb018899e613c537335b417b6414ca2581bf72ee254acd':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  679          2017-06-15       0.0    1071.0        2.0
#  685          2017-06-16       0.0    1064.0        2.0
#  694          2017-06-17       0.0    1066.0        2.0
#  699          2017-06-18       0.0    1056.0        2.0
#  706          2017-06-19       0.0    1054.0        2.0
#  ...                 ...       ...       ...        ...
#  121657       2022-05-27       0.0     639.0       91.0
#  121850       2022-05-28       0.0     639.0       91.0
#  121954       2022-05-29       0.0     639.0       91.0
#  122235       2022-05-30       0.0     639.0       91.0
#  122264       2022-05-31       0.0     639.0       91.0
#
#                                                  WELL_NAME
#  679     fb40f51a63a63fb7fbdb018899e613c537335b417b6414...
#  685     fb40f51a63a63fb7fbdb018899e613c537335b417b6414...
#  694     fb40f51a63a63fb7fbdb018899e613c537335b417b6414...
#  699     fb40f51a63a63fb7fbdb018899e613c537335b417b6414...
#  706     fb40f51a63a63fb7fbdb018899e613c537335b417b6414...
#  ...                                                   ...
#  121657  fb40f51a63a63fb7fbdb018899e613c537335b417b6414...
#  121850  fb40f51a63a63fb7fbdb018899e613c537335b417b6414...
#  121954  fb40f51a63a63fb7fbdb018899e613c537335b417b6414...
#  122235  fb40f51a63a63fb7fbdb018899e613c537335b417b6414...
#  122264  fb40f51a63a63fb7fbdb018899e613c537335b417b6414...
#
#  [1796 rows x 5 columns],
#  '8d22b7914a9aaa3ecfa0e00324f94210776ab6de9a3503d592a456a23670c4fa':        MEASURED_IN_DATE  CHARWORK     LIQ_RATE  WATER_CUT  \
#  980          2017-08-04       0.0  1210.000000   1.000000
#  987          2017-08-05       0.0  1210.000000   1.000000
#  998          2017-08-06       0.0  1210.000000   1.000000
#  1004         2017-08-07       0.0  1210.000000   1.000000
#  1010         2017-08-08       0.0  1210.000000   1.000000
#  ...                 ...       ...          ...        ...
#  121469       2022-05-26       0.0   844.028986  78.652174
#  121642       2022-05-27       0.0   843.970588  78.617647
#  121813       2022-05-28       0.0   824.000000  74.000000
#  121971       2022-05-29       0.0   824.000000  74.000000
#  122126       2022-05-30       0.0   824.000000  74.000000
#
#                                                  WELL_NAME
#  980     8d22b7914a9aaa3ecfa0e00324f94210776ab6de9a3503...
#  987     8d22b7914a9aaa3ecfa0e00324f94210776ab6de9a3503...
#  998     8d22b7914a9aaa3ecfa0e00324f94210776ab6de9a3503...
#  1004    8d22b7914a9aaa3ecfa0e00324f94210776ab6de9a3503...
#  1010    8d22b7914a9aaa3ecfa0e00324f94210776ab6de9a3503...
#  ...                                                   ...
#  121469  8d22b7914a9aaa3ecfa0e00324f94210776ab6de9a3503...
#  121642  8d22b7914a9aaa3ecfa0e00324f94210776ab6de9a3503...
#  121813  8d22b7914a9aaa3ecfa0e00324f94210776ab6de9a3503...
#  121971  8d22b7914a9aaa3ecfa0e00324f94210776ab6de9a3503...
#  122126  8d22b7914a9aaa3ecfa0e00324f94210776ab6de9a3503...
#
#  [1741 rows x 5 columns],
#  'cce7e6db14c3e631b6bd50568054c468045b6a265899c020dd0f01d4944d9465':        MEASURED_IN_DATE  CHARWORK     LIQ_RATE  WATER_CUT  \
#  1118         2017-08-24       0.0  1222.000000   1.000000
#  1131         2017-08-25       0.0  1222.000000   1.000000
#  1135         2017-08-26       0.0  1189.000000   1.000000
#  1143         2017-08-27       0.0  1189.000000   1.000000
#  1150         2017-08-28       0.0  1143.000000   1.000000
#  ...                 ...       ...          ...        ...
#  121494       2022-05-26       0.0  1348.695122  83.963415
#  121579       2022-05-27       0.0  1318.000000  86.000000
#  121763       2022-05-28       0.0  1318.000000  86.000000
#  122017       2022-05-29       0.0  1318.000000  86.000000
#  122123       2022-05-30       0.0  1318.000000  86.000000
#
#                                                  WELL_NAME
#  1118    cce7e6db14c3e631b6bd50568054c468045b6a265899c0...
#  1131    cce7e6db14c3e631b6bd50568054c468045b6a265899c0...
#  1135    cce7e6db14c3e631b6bd50568054c468045b6a265899c0...
#  1143    cce7e6db14c3e631b6bd50568054c468045b6a265899c0...
#  1150    cce7e6db14c3e631b6bd50568054c468045b6a265899c0...
#  ...                                                   ...
#  121494  cce7e6db14c3e631b6bd50568054c468045b6a265899c0...
#  121579  cce7e6db14c3e631b6bd50568054c468045b6a265899c0...
#  121763  cce7e6db14c3e631b6bd50568054c468045b6a265899c0...
#  122017  cce7e6db14c3e631b6bd50568054c468045b6a265899c0...
#  122123  cce7e6db14c3e631b6bd50568054c468045b6a265899c0...
#
#  [1722 rows x 5 columns],
#  '8a86c3f57690ec5f478e780c17281996c5e0b9b70bbdfd452a61ec20a0f5d9ab':        MEASURED_IN_DATE  CHARWORK    LIQ_RATE  WATER_CUT  \
#  1599         2017-10-23       0.0  231.000000   70.00000
#  1609         2017-10-24       0.0  231.000000   70.00000
#  1620         2017-10-25       0.0  231.000000   70.00000
#  1626         2017-10-26       0.0  230.000000   69.00000
#  1639         2017-10-27       0.0  230.000000   69.00000
#  ...                 ...       ...         ...        ...
#  121462       2022-05-26       0.0  445.915285   70.46593
#  121684       2022-05-27       0.0  346.000000   84.00000
#  121831       2022-05-28       0.0  346.000000   84.00000
#  121943       2022-05-29       0.0  346.000000   84.00000
#  122169       2022-05-30       0.0  346.000000   84.00000
#
#                                                  WELL_NAME
#  1599    8a86c3f57690ec5f478e780c17281996c5e0b9b70bbdfd...
#  1609    8a86c3f57690ec5f478e780c17281996c5e0b9b70bbdfd...
#  1620    8a86c3f57690ec5f478e780c17281996c5e0b9b70bbdfd...
#  1626    8a86c3f57690ec5f478e780c17281996c5e0b9b70bbdfd...
#  1639    8a86c3f57690ec5f478e780c17281996c5e0b9b70bbdfd...
#  ...                                                   ...
#  121462  8a86c3f57690ec5f478e780c17281996c5e0b9b70bbdfd...
#  121684  8a86c3f57690ec5f478e780c17281996c5e0b9b70bbdfd...
#  121831  8a86c3f57690ec5f478e780c17281996c5e0b9b70bbdfd...
#  121943  8a86c3f57690ec5f478e780c17281996c5e0b9b70bbdfd...
#  122169  8a86c3f57690ec5f478e780c17281996c5e0b9b70bbdfd...
#
#  [1673 rows x 5 columns],
#  '10d49b5fa61178ffad5d43e493be05a9336f2c2281e197b50b3cd2e783e2099e':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  1876         2017-11-23       0.0     668.0       34.0
#  1887         2017-11-24       0.0     668.0       34.0
#  1898         2017-11-25       0.0     668.0       34.0
#  1916         2017-11-26       0.0     668.0       34.0
#  1928         2017-11-27       0.0     668.0       34.0
#  ...                 ...       ...       ...        ...
#  121572       2022-05-27       0.0     579.0       85.0
#  121775       2022-05-28       0.0     579.0       85.0
#  122041       2022-05-29       0.0     579.0       85.0
#  122106       2022-05-30       0.0     579.0       85.0
#  122372       2022-05-31       0.0     579.0       86.0
#
#                                                  WELL_NAME
#  1876    10d49b5fa61178ffad5d43e493be05a9336f2c2281e197...
#  1887    10d49b5fa61178ffad5d43e493be05a9336f2c2281e197...
#  1898    10d49b5fa61178ffad5d43e493be05a9336f2c2281e197...
#  1916    10d49b5fa61178ffad5d43e493be05a9336f2c2281e197...
#  1928    10d49b5fa61178ffad5d43e493be05a9336f2c2281e197...
#  ...                                                   ...
#  121572  10d49b5fa61178ffad5d43e493be05a9336f2c2281e197...
#  121775  10d49b5fa61178ffad5d43e493be05a9336f2c2281e197...
#  122041  10d49b5fa61178ffad5d43e493be05a9336f2c2281e197...
#  122106  10d49b5fa61178ffad5d43e493be05a9336f2c2281e197...
#  122372  10d49b5fa61178ffad5d43e493be05a9336f2c2281e197...
#
#  [1632 rows x 5 columns],
#  'c54cb5885ae1f363434f0db35623507864b5aa43fe82cd94861a0ee7213c8a90':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  1877         2017-11-23       0.0     719.0       64.0
#  1891         2017-11-24       0.0     719.0       64.0
#  1900         2017-11-25       0.0     719.0       64.0
#  1909         2017-11-26       0.0     719.0       64.0
#  1920         2017-11-27       0.0     719.0       64.0
#  ...                 ...       ...       ...        ...
#  121636       2022-05-27       0.0     311.0       48.0
#  121792       2022-05-28       0.0     311.0       48.0
#  122013       2022-05-29       0.0     311.0       48.0
#  122086       2022-05-30       0.0     304.0       48.0
#  122269       2022-05-31       0.0     310.0       48.0
#
#                                                  WELL_NAME
#  1877    c54cb5885ae1f363434f0db35623507864b5aa43fe82cd...
#  1891    c54cb5885ae1f363434f0db35623507864b5aa43fe82cd...
#  1900    c54cb5885ae1f363434f0db35623507864b5aa43fe82cd...
#  1909    c54cb5885ae1f363434f0db35623507864b5aa43fe82cd...
#  1920    c54cb5885ae1f363434f0db35623507864b5aa43fe82cd...
#  ...                                                   ...
#  121636  c54cb5885ae1f363434f0db35623507864b5aa43fe82cd...
#  121792  c54cb5885ae1f363434f0db35623507864b5aa43fe82cd...
#  122013  c54cb5885ae1f363434f0db35623507864b5aa43fe82cd...
#  122086  c54cb5885ae1f363434f0db35623507864b5aa43fe82cd...
#  122269  c54cb5885ae1f363434f0db35623507864b5aa43fe82cd...
#
#  [1645 rows x 5 columns],
#  '5229c22a25eca7d2de860400dbc7e76e49b18dfcecea04998c034663d0a53c35':        MEASURED_IN_DATE  CHARWORK    LIQ_RATE  WATER_CUT  \
#  2037         2017-12-07       0.0  224.000000   2.000000
#  2049         2017-12-08       0.0  224.000000   2.000000
#  2052         2017-12-09       0.0  228.000000   2.000000
#  2072         2017-12-10       0.0  227.000000   2.000000
#  2080         2017-12-11       0.0  226.000000   2.000000
#  ...                 ...       ...         ...        ...
#  121389       2022-05-26       0.0  414.198758  85.285714
#  121590       2022-05-27       0.0  365.000000  86.000000
#  121893       2022-05-28       0.0  365.000000  86.000000
#  122008       2022-05-29       0.0  365.000000  86.000000
#  122090       2022-05-30       0.0  365.000000  86.000000
#
#                                                  WELL_NAME
#  2037    5229c22a25eca7d2de860400dbc7e76e49b18dfcecea04...
#  2049    5229c22a25eca7d2de860400dbc7e76e49b18dfcecea04...
#  2052    5229c22a25eca7d2de860400dbc7e76e49b18dfcecea04...
#  2072    5229c22a25eca7d2de860400dbc7e76e49b18dfcecea04...
#  2080    5229c22a25eca7d2de860400dbc7e76e49b18dfcecea04...
#  ...                                                   ...
#  121389  5229c22a25eca7d2de860400dbc7e76e49b18dfcecea04...
#  121590  5229c22a25eca7d2de860400dbc7e76e49b18dfcecea04...
#  121893  5229c22a25eca7d2de860400dbc7e76e49b18dfcecea04...
#  122008  5229c22a25eca7d2de860400dbc7e76e49b18dfcecea04...
#  122090  5229c22a25eca7d2de860400dbc7e76e49b18dfcecea04...
#
#  [1623 rows x 5 columns],
#  '8a413fd5c3facf80b1f840e5ab25849f068d1662b8d6d344c5159d473ecdd318':        MEASURED_IN_DATE  CHARWORK    LIQ_RATE  WATER_CUT  \
#  2457         2018-01-12       0.0  268.000000  91.000000
#  2473         2018-01-13       0.0  267.000000  91.000000
#  2488         2018-01-14       0.0  267.000000  91.000000
#  2501         2018-01-15       0.0  240.000000  91.000000
#  2512         2018-01-16       0.0  221.000000  87.000000
#  ...                 ...       ...         ...        ...
#  121405       2022-05-26       0.0  779.520796  90.835443
#  121617       2022-05-27       0.0  663.000000  91.000000
#  121874       2022-05-28       0.0  663.000000  91.000000
#  122023       2022-05-29       0.0  663.000000  91.000000
#  122259       2022-05-30       0.0  663.000000  91.000000
#
#                                                  WELL_NAME
#  2457    8a413fd5c3facf80b1f840e5ab25849f068d1662b8d6d3...
#  2473    8a413fd5c3facf80b1f840e5ab25849f068d1662b8d6d3...
#  2488    8a413fd5c3facf80b1f840e5ab25849f068d1662b8d6d3...
#  2501    8a413fd5c3facf80b1f840e5ab25849f068d1662b8d6d3...
#  2512    8a413fd5c3facf80b1f840e5ab25849f068d1662b8d6d3...
#  ...                                                   ...
#  121405  8a413fd5c3facf80b1f840e5ab25849f068d1662b8d6d3...
#  121617  8a413fd5c3facf80b1f840e5ab25849f068d1662b8d6d3...
#  121874  8a413fd5c3facf80b1f840e5ab25849f068d1662b8d6d3...
#  122023  8a413fd5c3facf80b1f840e5ab25849f068d1662b8d6d3...
#  122259  8a413fd5c3facf80b1f840e5ab25849f068d1662b8d6d3...
#
#  [1588 rows x 5 columns],
#  '96184ceab9c321bafb53b5e1c71df538d5435024098682fa1569003cafd35d22':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  2821         2018-02-09       0.0     518.0       29.0
#  2841         2018-02-10       0.0     518.0       29.0
#  2847         2018-02-11       0.0     518.0       29.0
#  2867         2018-02-12       0.0     518.0       29.0
#  2881         2018-02-13       0.0     518.0       29.0
#  ...                 ...       ...       ...        ...
#  121656       2022-05-27       0.0     182.0       49.0
#  121841       2022-05-28       0.0     182.0       49.0
#  121910       2022-05-29       0.0     182.0       49.0
#  122241       2022-05-30       0.0     182.0       49.0
#  122364       2022-05-31       0.0     182.0       50.0
#
#                                                  WELL_NAME
#  2821    96184ceab9c321bafb53b5e1c71df538d5435024098682...
#  2841    96184ceab9c321bafb53b5e1c71df538d5435024098682...
#  2847    96184ceab9c321bafb53b5e1c71df538d5435024098682...
#  2867    96184ceab9c321bafb53b5e1c71df538d5435024098682...
#  2881    96184ceab9c321bafb53b5e1c71df538d5435024098682...
#  ...                                                   ...
#  121656  96184ceab9c321bafb53b5e1c71df538d5435024098682...
#  121841  96184ceab9c321bafb53b5e1c71df538d5435024098682...
#  121910  96184ceab9c321bafb53b5e1c71df538d5435024098682...
#  122241  96184ceab9c321bafb53b5e1c71df538d5435024098682...
#  122364  96184ceab9c321bafb53b5e1c71df538d5435024098682...
#
#  [1556 rows x 5 columns],
#  '879329a0f238b019636f868a76bcbca2114b2b4135938f05efd60a12e6a79a2b':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  3484         2018-03-28       0.0     221.0       21.0
#  3501         2018-03-29       0.0     221.0       37.0
#  3516         2018-03-30       0.0     221.0       43.0
#  3528         2018-03-31       0.0     227.0       43.0
#  3536         2018-04-01       0.0     227.0       52.0
#  ...                 ...       ...       ...        ...
#  121625       2022-05-27       0.0     497.0       90.0
#  121801       2022-05-28       0.0     497.0       90.0
#  122001       2022-05-29       0.0     497.0       90.0
#  122160       2022-05-30       0.0     497.0       90.0
#  122361       2022-05-31       0.0     497.0       90.0
#
#                                                  WELL_NAME
#  3484    879329a0f238b019636f868a76bcbca2114b2b4135938f...
#  3501    879329a0f238b019636f868a76bcbca2114b2b4135938f...
#  3516    879329a0f238b019636f868a76bcbca2114b2b4135938f...
#  3528    879329a0f238b019636f868a76bcbca2114b2b4135938f...
#  3536    879329a0f238b019636f868a76bcbca2114b2b4135938f...
#  ...                                                   ...
#  121625  879329a0f238b019636f868a76bcbca2114b2b4135938f...
#  121801  879329a0f238b019636f868a76bcbca2114b2b4135938f...
#  122001  879329a0f238b019636f868a76bcbca2114b2b4135938f...
#  122160  879329a0f238b019636f868a76bcbca2114b2b4135938f...
#  122361  879329a0f238b019636f868a76bcbca2114b2b4135938f...
#
#  [1511 rows x 5 columns],
#  '8a7082479cad6c4a3ce75e82cd9a508b2199f5abab971c0006d0dcd95693a1b2':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  3800         2018-04-18       0.0     428.0       10.0
#  3807         2018-04-19       0.0     428.0       11.0
#  3831         2018-04-20       0.0     428.0       11.0
#  3833         2018-04-21       0.0     428.0       11.0
#  3857         2018-04-22       0.0     428.0       12.0
#  ...                 ...       ...       ...        ...
#  121603       2022-05-27       0.0     307.0       95.0
#  121872       2022-05-28       0.0     279.0       95.0
#  122025       2022-05-29       0.0     288.0       95.0
#  122151       2022-05-30       0.0     397.0       95.0
#  122366       2022-05-31       0.0     396.0       95.0
#
#                                                  WELL_NAME
#  3800    8a7082479cad6c4a3ce75e82cd9a508b2199f5abab971c...
#  3807    8a7082479cad6c4a3ce75e82cd9a508b2199f5abab971c...
#  3831    8a7082479cad6c4a3ce75e82cd9a508b2199f5abab971c...
#  3833    8a7082479cad6c4a3ce75e82cd9a508b2199f5abab971c...
#  3857    8a7082479cad6c4a3ce75e82cd9a508b2199f5abab971c...
#  ...                                                   ...
#  121603  8a7082479cad6c4a3ce75e82cd9a508b2199f5abab971c...
#  121872  8a7082479cad6c4a3ce75e82cd9a508b2199f5abab971c...
#  122025  8a7082479cad6c4a3ce75e82cd9a508b2199f5abab971c...
#  122151  8a7082479cad6c4a3ce75e82cd9a508b2199f5abab971c...
#  122366  8a7082479cad6c4a3ce75e82cd9a508b2199f5abab971c...
#
#  [1491 rows x 5 columns],
#  '42b038fe65f564902f2ba6c01df165599435d16c536c082c08b7ba0c2203c7f8':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  4472         2018-05-31       0.0     606.0       50.0
#  4487         2018-06-01       0.0     606.0       50.0
#  4508         2018-06-02       0.0     606.0       50.0
#  4529         2018-06-03       0.0     606.0       50.0
#  4547         2018-06-04       0.0     606.0       50.0
#  ...                 ...       ...       ...        ...
#  121647       2022-05-27       0.0     196.0       34.0
#  121803       2022-05-28       0.0     196.0       34.0
#  121911       2022-05-29       0.0     196.0       34.0
#  122177       2022-05-30       0.0     176.0       34.0
#  122263       2022-05-31       0.0     176.0       35.0
#
#                                                  WELL_NAME
#  4472    42b038fe65f564902f2ba6c01df165599435d16c536c08...
#  4487    42b038fe65f564902f2ba6c01df165599435d16c536c08...
#  4508    42b038fe65f564902f2ba6c01df165599435d16c536c08...
#  4529    42b038fe65f564902f2ba6c01df165599435d16c536c08...
#  4547    42b038fe65f564902f2ba6c01df165599435d16c536c08...
#  ...                                                   ...
#  121647  42b038fe65f564902f2ba6c01df165599435d16c536c08...
#  121803  42b038fe65f564902f2ba6c01df165599435d16c536c08...
#  121911  42b038fe65f564902f2ba6c01df165599435d16c536c08...
#  122177  42b038fe65f564902f2ba6c01df165599435d16c536c08...
#  122263  42b038fe65f564902f2ba6c01df165599435d16c536c08...
#
#  [1454 rows x 5 columns],
#  '8550eb204ff6ffb9fb0ccc399372965ebccdfab7c37927bca29bcd45a4029a0b':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  4712         2018-06-14       0.0     553.0        6.0
#  4737         2018-06-15       0.0     553.0        6.0
#  4752         2018-06-16       0.0     553.0        6.0
#  4759         2018-06-17       0.0     553.0        6.0
#  4780         2018-06-18       0.0     553.0        6.0
#  ...                 ...       ...       ...        ...
#  121585       2022-05-27       0.0     444.0       76.0
#  121908       2022-05-28       0.0     320.0       76.0
#  122068       2022-05-29       0.0     320.0       76.0
#  122118       2022-05-30       0.0     320.0       76.0
#  122352       2022-05-31       0.0     320.0       76.0
#
#                                                  WELL_NAME
#  4712    8550eb204ff6ffb9fb0ccc399372965ebccdfab7c37927...
#  4737    8550eb204ff6ffb9fb0ccc399372965ebccdfab7c37927...
#  4752    8550eb204ff6ffb9fb0ccc399372965ebccdfab7c37927...
#  4759    8550eb204ff6ffb9fb0ccc399372965ebccdfab7c37927...
#  4780    8550eb204ff6ffb9fb0ccc399372965ebccdfab7c37927...
#  ...                                                   ...
#  121585  8550eb204ff6ffb9fb0ccc399372965ebccdfab7c37927...
#  121908  8550eb204ff6ffb9fb0ccc399372965ebccdfab7c37927...
#  122068  8550eb204ff6ffb9fb0ccc399372965ebccdfab7c37927...
#  122118  8550eb204ff6ffb9fb0ccc399372965ebccdfab7c37927...
#  122352  8550eb204ff6ffb9fb0ccc399372965ebccdfab7c37927...
#
#  [1438 rows x 5 columns],
#  'a1661d2f54d25c16b8b3616d6683118d3c2f10b1af3968a05bbeb36f0d8dc5b0':        MEASURED_IN_DATE  CHARWORK    LIQ_RATE  WATER_CUT  \
#  4991         2018-06-30       0.0  124.000000  11.000000
#  5008         2018-07-01       0.0  124.000000   1.000000
#  5024         2018-07-02       0.0  124.000000   1.000000
#  5052         2018-07-03       0.0  124.000000   1.000000
#  5072         2018-07-04       0.0  124.000000   1.000000
#  ...                 ...       ...         ...        ...
#  121524       2022-05-26       0.0  322.584906  82.566038
#  121569       2022-05-27       0.0  314.000000  84.000000
#  121864       2022-05-28       0.0  314.000000  84.000000
#  121999       2022-05-29       0.0  314.000000  84.000000
#  122204       2022-05-30       0.0  314.000000  84.000000
#
#                                                  WELL_NAME
#  4991    a1661d2f54d25c16b8b3616d6683118d3c2f10b1af3968...
#  5008    a1661d2f54d25c16b8b3616d6683118d3c2f10b1af3968...
#  5024    a1661d2f54d25c16b8b3616d6683118d3c2f10b1af3968...
#  5052    a1661d2f54d25c16b8b3616d6683118d3c2f10b1af3968...
#  5072    a1661d2f54d25c16b8b3616d6683118d3c2f10b1af3968...
#  ...                                                   ...
#  121524  a1661d2f54d25c16b8b3616d6683118d3c2f10b1af3968...
#  121569  a1661d2f54d25c16b8b3616d6683118d3c2f10b1af3968...
#  121864  a1661d2f54d25c16b8b3616d6683118d3c2f10b1af3968...
#  121999  a1661d2f54d25c16b8b3616d6683118d3c2f10b1af3968...
#  122204  a1661d2f54d25c16b8b3616d6683118d3c2f10b1af3968...
#
#  [1418 rows x 5 columns],
#  'debcf7a160692239563af8a9c8ba32c4ba067e747f19c8073055e2be5aeb4022':       MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  5165        2018-07-09       0.0     528.0       15.0
#  5191        2018-07-10       0.0     528.0       15.0
#  5197        2018-07-11       0.0     528.0       15.0
#  5213        2018-07-12       0.0     465.0       15.0
#  5248        2018-07-13       0.0     464.0       15.0
#  ...                ...       ...       ...        ...
#  98589       2022-01-15       0.0     442.0       91.0
#  98830       2022-01-16       0.0     435.0       91.0
#  99010       2022-01-17       0.0     435.0       91.0
#  99273       2022-01-18       0.0     438.0       91.0
#  99301       2022-01-19       0.0     438.0       90.0
#
#                                                 WELL_NAME
#  5165   debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
#  5191   debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
#  5197   debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
#  5213   debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
#  5248   debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
#  ...                                                  ...
#  98589  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
#  98830  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
#  99010  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
#  99273  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
#  99301  debcf7a160692239563af8a9c8ba32c4ba067e747f19c8...
#
#  [1278 rows x 5 columns],
#  '59e8ab92b257d0809933a49847143f08b2143d238856e8e0286530ea0f677637':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  6218         2018-08-31       0.0     370.0        4.0
#  6228         2018-09-01       0.0     373.0        4.0
#  6261         2018-09-02       0.0     359.0        4.0
#  6278         2018-09-03       0.0     359.0        4.0
#  6294         2018-09-04       0.0     339.0        3.0
#  ...                 ...       ...       ...        ...
#  121706       2022-05-27       0.0     474.0       90.0
#  121800       2022-05-28       0.0     474.0       90.0
#  122004       2022-05-29       0.0     474.0       90.0
#  122111       2022-05-30       0.0     474.0       90.0
#  122349       2022-05-31       0.0     474.0       90.0
#
#                                                  WELL_NAME
#  6218    59e8ab92b257d0809933a49847143f08b2143d238856e8...
#  6228    59e8ab92b257d0809933a49847143f08b2143d238856e8...
#  6261    59e8ab92b257d0809933a49847143f08b2143d238856e8...
#  6278    59e8ab92b257d0809933a49847143f08b2143d238856e8...
#  6294    59e8ab92b257d0809933a49847143f08b2143d238856e8...
#  ...                                                   ...
#  121706  59e8ab92b257d0809933a49847143f08b2143d238856e8...
#  121800  59e8ab92b257d0809933a49847143f08b2143d238856e8...
#  122004  59e8ab92b257d0809933a49847143f08b2143d238856e8...
#  122111  59e8ab92b257d0809933a49847143f08b2143d238856e8...
#  122349  59e8ab92b257d0809933a49847143f08b2143d238856e8...
#
#  [1359 rows x 5 columns],
#  '7687f20faa1aee38a6beec0cb63d9094563f278304210b3118e6a6671cf8d34d':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  6362         2018-09-07       0.0     165.0       11.0
#  6376         2018-09-08       0.0     165.0       11.0
#  6412         2018-09-09       0.0     165.0        9.0
#  6425         2018-09-10       0.0     165.0        9.0
#  6457         2018-09-11       0.0      88.0       13.0
#  ...                 ...       ...       ...        ...
#  121693       2022-05-27       0.0      74.0       51.0
#  121896       2022-05-28       0.0      74.0       51.0
#  121975       2022-05-29       0.0      74.0       51.0
#  122094       2022-05-30       0.0      74.0       51.0
#  122343       2022-05-31       0.0      74.0       51.0
#
#                                                  WELL_NAME
#  6362    7687f20faa1aee38a6beec0cb63d9094563f278304210b...
#  6376    7687f20faa1aee38a6beec0cb63d9094563f278304210b...
#  6412    7687f20faa1aee38a6beec0cb63d9094563f278304210b...
#  6425    7687f20faa1aee38a6beec0cb63d9094563f278304210b...
#  6457    7687f20faa1aee38a6beec0cb63d9094563f278304210b...
#  ...                                                   ...
#  121693  7687f20faa1aee38a6beec0cb63d9094563f278304210b...
#  121896  7687f20faa1aee38a6beec0cb63d9094563f278304210b...
#  121975  7687f20faa1aee38a6beec0cb63d9094563f278304210b...
#  122094  7687f20faa1aee38a6beec0cb63d9094563f278304210b...
#  122343  7687f20faa1aee38a6beec0cb63d9094563f278304210b...
#
#  [1348 rows x 5 columns],
#  '769384f0a6fe5cba75fc68a9e52395eb9b69fa8dab849ef795694a92183121c9':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  6538         2018-09-15       0.0     550.0       20.0
#  6559         2018-09-16       0.0     550.0       20.0
#  6586         2018-09-17       0.0     536.0       20.0
#  6605         2018-09-18       0.0     539.0       10.0
#  6633         2018-09-19       0.0     539.0       10.0
#  ...                 ...       ...       ...        ...
#  121667       2022-05-27       0.0     382.0       62.0
#  121740       2022-05-28       0.0     382.0       62.0
#  122029       2022-05-29       0.0     382.0       62.0
#  122180       2022-05-30       0.0     382.0       62.0
#  122354       2022-05-31       0.0     382.0       62.0
#
#                                                  WELL_NAME
#  6538    769384f0a6fe5cba75fc68a9e52395eb9b69fa8dab849e...
#  6559    769384f0a6fe5cba75fc68a9e52395eb9b69fa8dab849e...
#  6586    769384f0a6fe5cba75fc68a9e52395eb9b69fa8dab849e...
#  6605    769384f0a6fe5cba75fc68a9e52395eb9b69fa8dab849e...
#  6633    769384f0a6fe5cba75fc68a9e52395eb9b69fa8dab849e...
#  ...                                                   ...
#  121667  769384f0a6fe5cba75fc68a9e52395eb9b69fa8dab849e...
#  121740  769384f0a6fe5cba75fc68a9e52395eb9b69fa8dab849e...
#  122029  769384f0a6fe5cba75fc68a9e52395eb9b69fa8dab849e...
#  122180  769384f0a6fe5cba75fc68a9e52395eb9b69fa8dab849e...
#  122354  769384f0a6fe5cba75fc68a9e52395eb9b69fa8dab849e...
#
#  [1340 rows x 5 columns],
#  'd17f8ecf18a3f583dd4379169d6c66636b8ed1e9f462f4598455ffa9f7a4c58e':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  9045         2019-01-03       0.0     107.0       20.0
#  9081         2019-01-04       0.0     107.0       20.0
#  9089         2019-01-05       0.0     107.0       20.0
#  9128         2019-01-06       0.0     107.0       20.0
#  9148         2019-01-07       0.0     107.0       20.0
#  ...                 ...       ...       ...        ...
#  121677       2022-05-27       0.0     109.0       68.0
#  121855       2022-05-28       0.0     109.0       68.0
#  121913       2022-05-29       0.0     109.0       68.0
#  122243       2022-05-30       0.0     109.0       68.0
#  122355       2022-05-31       0.0     109.0       68.0
#
#                                                  WELL_NAME
#  9045    d17f8ecf18a3f583dd4379169d6c66636b8ed1e9f462f4...
#  9081    d17f8ecf18a3f583dd4379169d6c66636b8ed1e9f462f4...
#  9089    d17f8ecf18a3f583dd4379169d6c66636b8ed1e9f462f4...
#  9128    d17f8ecf18a3f583dd4379169d6c66636b8ed1e9f462f4...
#  9148    d17f8ecf18a3f583dd4379169d6c66636b8ed1e9f462f4...
#  ...                                                   ...
#  121677  d17f8ecf18a3f583dd4379169d6c66636b8ed1e9f462f4...
#  121855  d17f8ecf18a3f583dd4379169d6c66636b8ed1e9f462f4...
#  121913  d17f8ecf18a3f583dd4379169d6c66636b8ed1e9f462f4...
#  122243  d17f8ecf18a3f583dd4379169d6c66636b8ed1e9f462f4...
#  122355  d17f8ecf18a3f583dd4379169d6c66636b8ed1e9f462f4...
#
#  [1235 rows x 5 columns],
#  'c4c3f5c05ed4de5a5a45cfd276fc5aafab4e4d6ca6a3ad8eb7d60214a7b578a4':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  9478         2019-01-21       0.0      99.0        7.0
#  9495         2019-01-22       0.0      99.0        7.0
#  9538         2019-01-23       0.0      99.0        7.0
#  9578         2019-01-25       0.0      99.0        7.0
#  9603         2019-01-26       0.0      99.0        7.0
#  ...                 ...       ...       ...        ...
#  121584       2022-05-27       0.0      64.0       41.0
#  121762       2022-05-28       0.0      64.0       41.0
#  121979       2022-05-29       0.0      64.0       41.0
#  122092       2022-05-30       0.0      64.0       41.0
#  122356       2022-05-31       0.0      64.0       41.0
#
#                                                  WELL_NAME
#  9478    c4c3f5c05ed4de5a5a45cfd276fc5aafab4e4d6ca6a3ad...
#  9495    c4c3f5c05ed4de5a5a45cfd276fc5aafab4e4d6ca6a3ad...
#  9538    c4c3f5c05ed4de5a5a45cfd276fc5aafab4e4d6ca6a3ad...
#  9578    c4c3f5c05ed4de5a5a45cfd276fc5aafab4e4d6ca6a3ad...
#  9603    c4c3f5c05ed4de5a5a45cfd276fc5aafab4e4d6ca6a3ad...
#  ...                                                   ...
#  121584  c4c3f5c05ed4de5a5a45cfd276fc5aafab4e4d6ca6a3ad...
#  121762  c4c3f5c05ed4de5a5a45cfd276fc5aafab4e4d6ca6a3ad...
#  121979  c4c3f5c05ed4de5a5a45cfd276fc5aafab4e4d6ca6a3ad...
#  122092  c4c3f5c05ed4de5a5a45cfd276fc5aafab4e4d6ca6a3ad...
#  122356  c4c3f5c05ed4de5a5a45cfd276fc5aafab4e4d6ca6a3ad...
#
#  [1217 rows x 5 columns],
#  'fa07c227692c1e41bb8ed4721811284dbefdb8de93e7b03b38586ba6568a6077':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  10230        2019-02-21       0.0      52.0       18.0
#  10266        2019-02-22       0.0      52.0       18.0
#  10305        2019-02-23       0.0      52.0       20.0
#  10309        2019-02-24       0.0      52.0       20.0
#  10339        2019-02-25       0.0      52.0       20.0
#  ...                 ...       ...       ...        ...
#  121714       2022-05-27       0.0      35.0       53.0
#  121753       2022-05-28       0.0      35.0       53.0
#  122022       2022-05-29       0.0      35.0       53.0
#  122250       2022-05-30       0.0      35.0       53.0
#  122346       2022-05-31       0.0      35.0       53.0
#
#                                                  WELL_NAME
#  10230   fa07c227692c1e41bb8ed4721811284dbefdb8de93e7b0...
#  10266   fa07c227692c1e41bb8ed4721811284dbefdb8de93e7b0...
#  10305   fa07c227692c1e41bb8ed4721811284dbefdb8de93e7b0...
#  10309   fa07c227692c1e41bb8ed4721811284dbefdb8de93e7b0...
#  10339   fa07c227692c1e41bb8ed4721811284dbefdb8de93e7b0...
#  ...                                                   ...
#  121714  fa07c227692c1e41bb8ed4721811284dbefdb8de93e7b0...
#  121753  fa07c227692c1e41bb8ed4721811284dbefdb8de93e7b0...
#  122022  fa07c227692c1e41bb8ed4721811284dbefdb8de93e7b0...
#  122250  fa07c227692c1e41bb8ed4721811284dbefdb8de93e7b0...
#  122346  fa07c227692c1e41bb8ed4721811284dbefdb8de93e7b0...
#
#  [1178 rows x 5 columns],
#  '981b1bba122807393498e5ef8a936c1e13c767ab2ea841ddf93a7e34e3b306cb':        MEASURED_IN_DATE  CHARWORK    LIQ_RATE  WATER_CUT  \
#  11879        2019-04-25       0.0  299.000000     11.000
#  11904        2019-04-26       0.0  298.000000     12.000
#  11910        2019-04-27       0.0  298.000000     12.000
#  11941        2019-04-28       0.0  296.000000     12.000
#  11986        2019-04-29       0.0  296.000000     12.000
#  ...                 ...       ...         ...        ...
#  121392       2022-05-26       0.0  747.821429     91.875
#  121596       2022-05-27       0.0  721.000000     93.000
#  121903       2022-05-28       0.0  721.000000     93.000
#  121917       2022-05-29       0.0  721.000000     93.000
#  122258       2022-05-30       0.0  721.000000     93.000
#
#                                                  WELL_NAME
#  11879   981b1bba122807393498e5ef8a936c1e13c767ab2ea841...
#  11904   981b1bba122807393498e5ef8a936c1e13c767ab2ea841...
#  11910   981b1bba122807393498e5ef8a936c1e13c767ab2ea841...
#  11941   981b1bba122807393498e5ef8a936c1e13c767ab2ea841...
#  11986   981b1bba122807393498e5ef8a936c1e13c767ab2ea841...
#  ...                                                   ...
#  121392  981b1bba122807393498e5ef8a936c1e13c767ab2ea841...
#  121596  981b1bba122807393498e5ef8a936c1e13c767ab2ea841...
#  121903  981b1bba122807393498e5ef8a936c1e13c767ab2ea841...
#  121917  981b1bba122807393498e5ef8a936c1e13c767ab2ea841...
#  122258  981b1bba122807393498e5ef8a936c1e13c767ab2ea841...
#
#  [1121 rows x 5 columns],
#  'a69910b63c068659d3736c032f22cc16848266fb55dc30f1cbd7b9d5f344de2b':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  15810        2019-09-20       0.0     407.0       11.0
#  15829        2019-09-21       0.0     407.0       11.0
#  15863        2019-09-22       0.0     407.0       11.0
#  15909        2019-09-23       0.0     436.0       12.0
#  15931        2019-09-24       0.0     436.0       12.0
#  ...                 ...       ...       ...        ...
#  121650       2022-05-27       0.0     299.0       77.0
#  121812       2022-05-28       0.0     299.0       77.0
#  121962       2022-05-29       0.0     311.0       77.0
#  122137       2022-05-30       0.0     310.0       77.0
#  122376       2022-05-31       0.0     316.0       77.0
#
#                                                  WELL_NAME
#  15810   a69910b63c068659d3736c032f22cc16848266fb55dc30...
#  15829   a69910b63c068659d3736c032f22cc16848266fb55dc30...
#  15863   a69910b63c068659d3736c032f22cc16848266fb55dc30...
#  15909   a69910b63c068659d3736c032f22cc16848266fb55dc30...
#  15931   a69910b63c068659d3736c032f22cc16848266fb55dc30...
#  ...                                                   ...
#  121650  a69910b63c068659d3736c032f22cc16848266fb55dc30...
#  121812  a69910b63c068659d3736c032f22cc16848266fb55dc30...
#  121962  a69910b63c068659d3736c032f22cc16848266fb55dc30...
#  122137  a69910b63c068659d3736c032f22cc16848266fb55dc30...
#  122376  a69910b63c068659d3736c032f22cc16848266fb55dc30...
#
#  [973 rows x 5 columns],
#  'b99d18a9e3d55dcce0e7826b5580cc1dcdb46ba9298993b37cfdd0add7e264a0':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  16412        2019-10-12       0.0     321.0       23.0
#  16457        2019-10-13       0.0     321.0       23.0
#  16477        2019-10-14       0.0     321.0       22.0
#  16525        2019-10-15       0.0     321.0       22.0
#  16537        2019-10-16       0.0     321.0       22.0
#  ...                 ...       ...       ...        ...
#  121728       2022-05-27       0.0     178.0       82.0
#  121757       2022-05-28       0.0     178.0       82.0
#  122066       2022-05-29       0.0     178.0       82.0
#  122091       2022-05-30       0.0     178.0       82.0
#  122345       2022-05-31       0.0     178.0       82.0
#
#                                                  WELL_NAME
#  16412   b99d18a9e3d55dcce0e7826b5580cc1dcdb46ba9298993...
#  16457   b99d18a9e3d55dcce0e7826b5580cc1dcdb46ba9298993...
#  16477   b99d18a9e3d55dcce0e7826b5580cc1dcdb46ba9298993...
#  16525   b99d18a9e3d55dcce0e7826b5580cc1dcdb46ba9298993...
#  16537   b99d18a9e3d55dcce0e7826b5580cc1dcdb46ba9298993...
#  ...                                                   ...
#  121728  b99d18a9e3d55dcce0e7826b5580cc1dcdb46ba9298993...
#  121757  b99d18a9e3d55dcce0e7826b5580cc1dcdb46ba9298993...
#  122066  b99d18a9e3d55dcce0e7826b5580cc1dcdb46ba9298993...
#  122091  b99d18a9e3d55dcce0e7826b5580cc1dcdb46ba9298993...
#  122345  b99d18a9e3d55dcce0e7826b5580cc1dcdb46ba9298993...
#
#  [958 rows x 5 columns],
#  '625dca26d9bd9387cc17e1c5e1905105ab4e1171623d04a48f5ff7bd9ba589e0':        MEASURED_IN_DATE  CHARWORK    LIQ_RATE  WATER_CUT  \
#  16425        2019-10-12       0.0  280.000000  10.000000
#  16445        2019-10-13       0.0  280.000000  10.000000
#  16498        2019-10-14       0.0  288.000000  10.000000
#  16502        2019-10-15       0.0  304.000000  10.000000
#  16536        2019-10-16       0.0  303.000000  10.000000
#  ...                 ...       ...         ...        ...
#  121700       2022-05-27       0.0   68.147059  14.705882
#  121889       2022-05-28       0.0   68.303030  14.696970
#  121944       2022-05-29       0.0   68.468750  14.687500
#  122209       2022-05-30       0.0   68.483871  14.677419
#  122344       2022-05-31       0.0   95.000000  22.000000
#
#                                                  WELL_NAME
#  16425   625dca26d9bd9387cc17e1c5e1905105ab4e1171623d04...
#  16445   625dca26d9bd9387cc17e1c5e1905105ab4e1171623d04...
#  16498   625dca26d9bd9387cc17e1c5e1905105ab4e1171623d04...
#  16502   625dca26d9bd9387cc17e1c5e1905105ab4e1171623d04...
#  16536   625dca26d9bd9387cc17e1c5e1905105ab4e1171623d04...
#  ...                                                   ...
#  121700  625dca26d9bd9387cc17e1c5e1905105ab4e1171623d04...
#  121889  625dca26d9bd9387cc17e1c5e1905105ab4e1171623d04...
#  121944  625dca26d9bd9387cc17e1c5e1905105ab4e1171623d04...
#  122209  625dca26d9bd9387cc17e1c5e1905105ab4e1171623d04...
#  122344  625dca26d9bd9387cc17e1c5e1905105ab4e1171623d04...
#
#  [957 rows x 5 columns],
#  'd0edc568d22b23ac9f12652d9e8fb69074a7dd0ea26053c7ebbb76b90a3e3e2c':        MEASURED_IN_DATE  CHARWORK     LIQ_RATE  WATER_CUT  \
#  16971        2019-10-30       0.0  1159.000000   2.000000
#  16982        2019-10-31       0.0  1159.000000   2.000000
#  17012        2019-11-01       0.0  1203.000000   2.000000
#  17047        2019-11-02       0.0  1203.000000   1.000000
#  17094        2019-11-03       0.0  1203.000000   1.000000
#  ...                 ...       ...          ...        ...
#  121412       2022-05-26       0.0   727.500000  55.678571
#  121733       2022-05-27       0.0   726.814815  55.703704
#  121829       2022-05-28       0.0   721.000000  55.000000
#  121952       2022-05-29       0.0   721.000000  55.000000
#  122173       2022-05-30       0.0   721.000000  55.000000
#
#                                                  WELL_NAME
#  16971   d0edc568d22b23ac9f12652d9e8fb69074a7dd0ea26053...
#  16982   d0edc568d22b23ac9f12652d9e8fb69074a7dd0ea26053...
#  17012   d0edc568d22b23ac9f12652d9e8fb69074a7dd0ea26053...
#  17047   d0edc568d22b23ac9f12652d9e8fb69074a7dd0ea26053...
#  17094   d0edc568d22b23ac9f12652d9e8fb69074a7dd0ea26053...
#  ...                                                   ...
#  121412  d0edc568d22b23ac9f12652d9e8fb69074a7dd0ea26053...
#  121733  d0edc568d22b23ac9f12652d9e8fb69074a7dd0ea26053...
#  121829  d0edc568d22b23ac9f12652d9e8fb69074a7dd0ea26053...
#  121952  d0edc568d22b23ac9f12652d9e8fb69074a7dd0ea26053...
#  122173  d0edc568d22b23ac9f12652d9e8fb69074a7dd0ea26053...
#
#  [932 rows x 5 columns],
# ...
#  79910   72eae73db0f2cb03169dffd08ed84a3016729812a74361...
#  79918   72eae73db0f2cb03169dffd08ed84a3016729812a74361...
#  ...                                                   ...
#  121689  72eae73db0f2cb03169dffd08ed84a3016729812a74361...
#  121835  72eae73db0f2cb03169dffd08ed84a3016729812a74361...
#  121936  72eae73db0f2cb03169dffd08ed84a3016729812a74361...
#  122186  72eae73db0f2cb03169dffd08ed84a3016729812a74361...
#  122375  72eae73db0f2cb03169dffd08ed84a3016729812a74361...
#
#  [244 rows x 5 columns],
#  '0846f99b079f2387f57b75626042cf6453971ae4f3d54f0d99428ff3e133ea89':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  79654        2021-09-28       0.0   511.000     18.000
#  79749        2021-09-29       0.0   511.000     18.000
#  80059        2021-09-30       0.0   494.000     18.000
#  80209        2021-10-01       0.0   494.000     17.000
#  80307        2021-10-02       0.0   494.000     17.000
#  ...                 ...       ...       ...        ...
#  121583       2022-05-27       0.0   315.875     76.375
#  121769       2022-05-28       0.0   317.000     81.000
#  122059       2022-05-29       0.0   317.000     81.000
#  122119       2022-05-30       0.0   317.000     81.000
#  122322       2022-05-31       0.0   317.000     81.000
#
#                                                  WELL_NAME
#  79654   0846f99b079f2387f57b75626042cf6453971ae4f3d54f...
#  79749   0846f99b079f2387f57b75626042cf6453971ae4f3d54f...
#  80059   0846f99b079f2387f57b75626042cf6453971ae4f3d54f...
#  80209   0846f99b079f2387f57b75626042cf6453971ae4f3d54f...
#  80307   0846f99b079f2387f57b75626042cf6453971ae4f3d54f...
#  ...                                                   ...
#  121583  0846f99b079f2387f57b75626042cf6453971ae4f3d54f...
#  121769  0846f99b079f2387f57b75626042cf6453971ae4f3d54f...
#  122059  0846f99b079f2387f57b75626042cf6453971ae4f3d54f...
#  122119  0846f99b079f2387f57b75626042cf6453971ae4f3d54f...
#  122322  0846f99b079f2387f57b75626042cf6453971ae4f3d54f...
#
#  [241 rows x 5 columns],
#  '736a83d0b05f9a1b6f490ed27f370062d596ff85802a2caddadb1bc0629dedcc':        MEASURED_IN_DATE  CHARWORK    LIQ_RATE  WATER_CUT  \
#  79660        2021-09-28       0.0  429.000000   4.000000
#  79751        2021-09-29       0.0  429.000000   4.000000
#  80085        2021-09-30       0.0  429.000000   4.000000
#  80185        2021-10-01       0.0  432.000000   6.000000
#  80375        2021-10-02       0.0  432.000000   6.000000
#  ...                 ...       ...         ...        ...
#  121526       2022-05-26       0.0  282.823529  23.823529
#  121674       2022-05-27       0.0  282.625000  23.937500
#  121780       2022-05-28       0.0  277.000000  31.000000
#  122052       2022-05-29       0.0  277.000000  31.000000
#  122215       2022-05-30       0.0  277.000000  31.000000
#
#                                                  WELL_NAME
#  79660   736a83d0b05f9a1b6f490ed27f370062d596ff85802a2c...
#  79751   736a83d0b05f9a1b6f490ed27f370062d596ff85802a2c...
#  80085   736a83d0b05f9a1b6f490ed27f370062d596ff85802a2c...
#  80185   736a83d0b05f9a1b6f490ed27f370062d596ff85802a2c...
#  80375   736a83d0b05f9a1b6f490ed27f370062d596ff85802a2c...
#  ...                                                   ...
#  121526  736a83d0b05f9a1b6f490ed27f370062d596ff85802a2c...
#  121674  736a83d0b05f9a1b6f490ed27f370062d596ff85802a2c...
#  121780  736a83d0b05f9a1b6f490ed27f370062d596ff85802a2c...
#  122052  736a83d0b05f9a1b6f490ed27f370062d596ff85802a2c...
#  122215  736a83d0b05f9a1b6f490ed27f370062d596ff85802a2c...
#
#  [240 rows x 5 columns],
#  '873b8e3a7c3e78d2fa7324782a2d9ccc4d326668146be0eb302e5dad52c9a3fc':        MEASURED_IN_DATE  CHARWORK    LIQ_RATE  WATER_CUT  \
#  80055        2021-09-30       0.0  302.000000   8.000000
#  80200        2021-10-01       0.0  302.000000   8.000000
#  80364        2021-10-02       0.0  301.000000   8.000000
#  80453        2021-10-03       0.0  301.000000   8.000000
#  80652        2021-10-04       0.0  301.000000   7.000000
#  ...                 ...       ...         ...        ...
#  121637       2022-05-27       0.0   72.190476   9.904762
#  121793       2022-05-28       0.0   72.000000   7.000000
#  121995       2022-05-29       0.0   72.000000   7.000000
#  122192       2022-05-30       0.0   72.000000   7.000000
#  122380       2022-05-31       0.0   68.000000   7.000000
#
#                                                  WELL_NAME
#  80055   873b8e3a7c3e78d2fa7324782a2d9ccc4d326668146be0...
#  80200   873b8e3a7c3e78d2fa7324782a2d9ccc4d326668146be0...
#  80364   873b8e3a7c3e78d2fa7324782a2d9ccc4d326668146be0...
#  80453   873b8e3a7c3e78d2fa7324782a2d9ccc4d326668146be0...
#  80652   873b8e3a7c3e78d2fa7324782a2d9ccc4d326668146be0...
#  ...                                                   ...
#  121637  873b8e3a7c3e78d2fa7324782a2d9ccc4d326668146be0...
#  121793  873b8e3a7c3e78d2fa7324782a2d9ccc4d326668146be0...
#  121995  873b8e3a7c3e78d2fa7324782a2d9ccc4d326668146be0...
#  122192  873b8e3a7c3e78d2fa7324782a2d9ccc4d326668146be0...
#  122380  873b8e3a7c3e78d2fa7324782a2d9ccc4d326668146be0...
#
#  [238 rows x 5 columns],
#  '4ad7272cf490cf85e327b0014942cfe320346814185b3d9cce06254e3d5194f2':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  80967        2021-10-06       0.0     153.0        2.0
#  81123        2021-10-07       0.0     153.0        2.0
#  81438        2021-10-08       0.0     153.0        2.0
#  81600        2021-10-09       0.0     153.0        2.0
#  81777        2021-10-10       0.0     153.0        2.0
#  ...                 ...       ...       ...        ...
#  121683       2022-05-27       0.0     121.0        4.0
#  121826       2022-05-28       0.0     119.0        4.0
#  121950       2022-05-29       0.0     114.0        4.0
#  122181       2022-05-30       0.0     116.0        4.0
#  122406       2022-05-31       0.0     119.0        4.0
#
#                                                  WELL_NAME
#  80967   4ad7272cf490cf85e327b0014942cfe320346814185b3d...
#  81123   4ad7272cf490cf85e327b0014942cfe320346814185b3d...
#  81438   4ad7272cf490cf85e327b0014942cfe320346814185b3d...
#  81600   4ad7272cf490cf85e327b0014942cfe320346814185b3d...
#  81777   4ad7272cf490cf85e327b0014942cfe320346814185b3d...
#  ...                                                   ...
#  121683  4ad7272cf490cf85e327b0014942cfe320346814185b3d...
#  121826  4ad7272cf490cf85e327b0014942cfe320346814185b3d...
#  121950  4ad7272cf490cf85e327b0014942cfe320346814185b3d...
#  122181  4ad7272cf490cf85e327b0014942cfe320346814185b3d...
#  122406  4ad7272cf490cf85e327b0014942cfe320346814185b3d...
#
#  [235 rows x 5 columns],
#  '7148a6537ac3d9de9b511814b068fce6bbfc56dfa3972a00db2fce888b4969c5':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  82128        2021-10-12       0.0     128.0     8.0000
#  82284        2021-10-13       0.0     128.0     8.0000
#  82504        2021-10-14       0.0     128.0     8.0000
#  82613        2021-10-15       0.0     128.0     8.0000
#  82738        2021-10-16       0.0     128.0     8.0000
#  ...                 ...       ...       ...        ...
#  121587       2022-05-27       0.0     127.0    59.6875
#  121865       2022-05-28       0.0     127.0    58.0000
#  121960       2022-05-29       0.0     127.0    58.0000
#  122129       2022-05-30       0.0     127.0    58.0000
#  122331       2022-05-31       0.0     127.0    58.0000
#
#                                                  WELL_NAME
#  82128   7148a6537ac3d9de9b511814b068fce6bbfc56dfa3972a...
#  82284   7148a6537ac3d9de9b511814b068fce6bbfc56dfa3972a...
#  82504   7148a6537ac3d9de9b511814b068fce6bbfc56dfa3972a...
#  82613   7148a6537ac3d9de9b511814b068fce6bbfc56dfa3972a...
#  82738   7148a6537ac3d9de9b511814b068fce6bbfc56dfa3972a...
#  ...                                                   ...
#  121587  7148a6537ac3d9de9b511814b068fce6bbfc56dfa3972a...
#  121865  7148a6537ac3d9de9b511814b068fce6bbfc56dfa3972a...
#  121960  7148a6537ac3d9de9b511814b068fce6bbfc56dfa3972a...
#  122129  7148a6537ac3d9de9b511814b068fce6bbfc56dfa3972a...
#  122331  7148a6537ac3d9de9b511814b068fce6bbfc56dfa3972a...
#
#  [226 rows x 5 columns],
#  '188db2c93903ffa6b8b5ebe1864c2ba78a710bc38b95d79a2fcee2d483f9d22b':        MEASURED_IN_DATE  CHARWORK    LIQ_RATE  WATER_CUT  \
#  82982        2021-10-17       0.0  491.000000  12.000000
#  83182        2021-10-19       0.0  491.000000  12.000000
#  83369        2021-10-20       0.0  491.000000  13.000000
#  83433        2021-10-21       0.0  491.000000  13.000000
#  83700        2021-10-22       0.0  491.000000  13.000000
#  ...                 ...       ...         ...        ...
#  121623       2022-05-27       0.0  495.058824  64.235294
#  121798       2022-05-28       0.0  512.000000  62.000000
#  122002       2022-05-29       0.0  512.000000  62.000000
#  122234       2022-05-30       0.0  512.000000  62.000000
#  122278       2022-05-31       0.0  490.000000  62.000000
#
#                                                  WELL_NAME
#  82982   188db2c93903ffa6b8b5ebe1864c2ba78a710bc38b95d7...
#  83182   188db2c93903ffa6b8b5ebe1864c2ba78a710bc38b95d7...
#  83369   188db2c93903ffa6b8b5ebe1864c2ba78a710bc38b95d7...
#  83433   188db2c93903ffa6b8b5ebe1864c2ba78a710bc38b95d7...
#  83700   188db2c93903ffa6b8b5ebe1864c2ba78a710bc38b95d7...
#  ...                                                   ...
#  121623  188db2c93903ffa6b8b5ebe1864c2ba78a710bc38b95d7...
#  121798  188db2c93903ffa6b8b5ebe1864c2ba78a710bc38b95d7...
#  122002  188db2c93903ffa6b8b5ebe1864c2ba78a710bc38b95d7...
#  122234  188db2c93903ffa6b8b5ebe1864c2ba78a710bc38b95d7...
#  122278  188db2c93903ffa6b8b5ebe1864c2ba78a710bc38b95d7...
#
#  [223 rows x 5 columns],
#  'bfa53be157c54a87bb5351d538b22bca531c31dd3d0343b2af0d5c617f1d356c':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  85209        2021-10-31       0.0    470.00     16.000
#  85446        2021-11-01       0.0    470.00     16.000
#  85661        2021-11-02       0.0    470.00     16.000
#  85717        2021-11-03       0.0    470.00     16.000
#  85992        2021-11-04       0.0    470.00     16.000
#  ...                 ...       ...       ...        ...
#  121681       2022-05-27       0.0    525.25     77.375
#  121853       2022-05-28       0.0    520.00     77.000
#  121968       2022-05-29       0.0    520.00     77.000
#  122140       2022-05-30       0.0    520.00     77.000
#  122277       2022-05-31       0.0    520.00     77.000
#
#                                                  WELL_NAME
#  85209   bfa53be157c54a87bb5351d538b22bca531c31dd3d0343...
#  85446   bfa53be157c54a87bb5351d538b22bca531c31dd3d0343...
#  85661   bfa53be157c54a87bb5351d538b22bca531c31dd3d0343...
#  85717   bfa53be157c54a87bb5351d538b22bca531c31dd3d0343...
#  85992   bfa53be157c54a87bb5351d538b22bca531c31dd3d0343...
#  ...                                                   ...
#  121681  bfa53be157c54a87bb5351d538b22bca531c31dd3d0343...
#  121853  bfa53be157c54a87bb5351d538b22bca531c31dd3d0343...
#  121968  bfa53be157c54a87bb5351d538b22bca531c31dd3d0343...
#  122140  bfa53be157c54a87bb5351d538b22bca531c31dd3d0343...
#  122277  bfa53be157c54a87bb5351d538b22bca531c31dd3d0343...
#
#  [210 rows x 5 columns],
#  '78abd7bc797c6ba4d6d5ca2bf94d8d6fae97effc20159078aefb61de55a1540f':        MEASURED_IN_DATE  CHARWORK    LIQ_RATE  WATER_CUT  \
#  89323        2021-11-23       0.0  442.000000   9.000000
#  89478        2021-11-24       0.0  442.000000   9.000000
#  89670        2021-11-25       0.0  442.000000   9.000000
#  89760        2021-11-26       0.0  442.000000   9.000000
#  90009        2021-11-27       0.0  442.000000   9.000000
#  ...                 ...       ...         ...        ...
#  121472       2022-05-26       0.0  483.500000  12.222222
#  121646       2022-05-27       0.0  483.705882  12.117647
#  121818       2022-05-28       0.0  487.000000  11.000000
#  121965       2022-05-29       0.0  487.000000  11.000000
#  122089       2022-05-30       0.0  487.000000  11.000000
#
#                                                  WELL_NAME
#  89323   78abd7bc797c6ba4d6d5ca2bf94d8d6fae97effc201590...
#  89478   78abd7bc797c6ba4d6d5ca2bf94d8d6fae97effc201590...
#  89670   78abd7bc797c6ba4d6d5ca2bf94d8d6fae97effc201590...
#  89760   78abd7bc797c6ba4d6d5ca2bf94d8d6fae97effc201590...
#  90009   78abd7bc797c6ba4d6d5ca2bf94d8d6fae97effc201590...
#  ...                                                   ...
#  121472  78abd7bc797c6ba4d6d5ca2bf94d8d6fae97effc201590...
#  121646  78abd7bc797c6ba4d6d5ca2bf94d8d6fae97effc201590...
#  121818  78abd7bc797c6ba4d6d5ca2bf94d8d6fae97effc201590...
#  121965  78abd7bc797c6ba4d6d5ca2bf94d8d6fae97effc201590...
#  122089  78abd7bc797c6ba4d6d5ca2bf94d8d6fae97effc201590...
#
#  [186 rows x 5 columns],
#  '1de41569155b66df7355c8fc7a53e80333aea79dc9bb373a2aef7db9d277e61f':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  89728        2021-11-25       0.0     521.0       10.0
#  89777        2021-11-26       0.0     521.0       10.0
#  89996        2021-11-27       0.0     521.0       10.0
#  90249        2021-11-28       0.0     521.0       10.0
#  90267        2021-11-29       0.0     521.0        7.0
#  ...                 ...       ...       ...        ...
#  121653       2022-05-27       0.0     328.0       70.0
#  121820       2022-05-28       0.0     328.0       70.0
#  121982       2022-05-29       0.0     328.0       70.0
#  122108       2022-05-30       0.0     328.0       70.0
#  122411       2022-05-31       0.0     328.0       70.0
#
#                                                  WELL_NAME
#  89728   1de41569155b66df7355c8fc7a53e80333aea79dc9bb37...
#  89777   1de41569155b66df7355c8fc7a53e80333aea79dc9bb37...
#  89996   1de41569155b66df7355c8fc7a53e80333aea79dc9bb37...
#  90249   1de41569155b66df7355c8fc7a53e80333aea79dc9bb37...
#  90267   1de41569155b66df7355c8fc7a53e80333aea79dc9bb37...
#  ...                                                   ...
#  121653  1de41569155b66df7355c8fc7a53e80333aea79dc9bb37...
#  121820  1de41569155b66df7355c8fc7a53e80333aea79dc9bb37...
#  121982  1de41569155b66df7355c8fc7a53e80333aea79dc9bb37...
#  122108  1de41569155b66df7355c8fc7a53e80333aea79dc9bb37...
#  122411  1de41569155b66df7355c8fc7a53e80333aea79dc9bb37...
#
#  [183 rows x 5 columns],
#  'fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f80531922ce3085056f9':        MEASURED_IN_DATE  CHARWORK  LIQ_RATE  WATER_CUT  \
#  90147        2021-11-28       0.0     460.0  16.000000
#  90406        2021-11-29       0.0     460.0  16.000000
#  90452        2021-11-30       0.0     460.0  16.000000
#  90725        2021-12-01       0.0     460.0  16.000000
#  90909        2021-12-02       0.0     492.0  16.000000
#  ...                 ...       ...       ...        ...
#  121591       2022-05-27       0.0     462.0  42.352941
#  121879       2022-05-28       0.0     454.0  42.000000
#  121964       2022-05-29       0.0     454.0  42.000000
#  122155       2022-05-30       0.0     454.0  42.000000
#  122272       2022-05-31       0.0     480.0  42.000000
#
#                                                  WELL_NAME
#  90147   fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
#  90406   fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
#  90452   fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
#  90725   fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
#  90909   fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
#  ...                                                   ...
#  121591  fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
#  121879  fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
#  121964  fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
#  122155  fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
#  122272  fe15ccab850c10f95481f1309a2e9f88e1458be2a8a8f8...
#
#  [182 rows x 5 columns]}
